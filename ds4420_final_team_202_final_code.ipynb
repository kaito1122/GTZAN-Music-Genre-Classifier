# %%
# !pip install Pydub
# !pip install PyWavelets
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import pywt
import pandas as pd
import os
from sklearn.preprocessing import StandardScaler, LabelEncoder
import audioread
from pydub import AudioSegment
import tensorflow as tf
from tensorflow.keras import layers, models
import audioread
import tensorflow_hub as hub
from keras import layers, models, preprocessing
import keras.backend as K
from keras.preprocessing.sequence import pad_sequences
from keras import mixed_precision
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.callbacks import LearningRateScheduler
import math
import random
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import Callback
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, log_loss, confusion_matrix
import seaborn as sns
# Out:
# Requirement already satisfied: Pydub in /usr/local/lib/python3.10/dist-packages (0.25.1)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.10/dist-packages (1.8.0)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.10/dist-packages (from PyWavelets) (1.26.4)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Data Preprocessing

# %%
# Load the datasets
file_30_sec = '/content/drive/MyDrive/DS4420_Project/data/GTZAN/features_30_sec.csv'
audio_directory = '/content/drive/MyDrive/DS4420_Project/data/GTZAN/genres_original'
#image_directory = '/content/drive/MyDrive/DS4420_Project/data/GTZAN/images_original'

df_30_sec = pd.read_csv(file_30_sec)

# Function to generate summary statistics for audio files
def audio_summary_statistics(audio_directory):
    summary_statistics = []

    for genre_folder in os.listdir(audio_directory):
        genre_path = os.path.join(audio_directory, genre_folder)
        if not os.path.isdir(genre_path):
            continue

        for audio_file in os.listdir(genre_path):
            if audio_file.endswith('.wav'):
                file_path = os.path.join(genre_path, audio_file)

                try:
                    # Load the audio file
                    y, sr = librosa.load(file_path, sr=None)

                    # Calculate summary statistics
                    duration = librosa.get_duration(y=y, sr=sr)
                    mean_amplitude = np.mean(np.abs(y))
                    rms_amplitude = np.sqrt(np.mean(y**2))
                    max_amplitude = np.max(np.abs(y))

                    summary_statistics.append({
                        'Genre': genre_folder,
                        'Filename': audio_file,
                        'Duration (s)': duration,
                        'Sampling Rate': sr,
                        'Mean Amplitude': mean_amplitude,
                        'RMS Amplitude': rms_amplitude,
                        'Max Amplitude': max_amplitude
                    })

                except Exception as e:
                    print(f"Error processing {file_path}: {e}")
                    continue

    # Convert to DataFrame for easier readability
    summary_df = pd.DataFrame(summary_statistics)
    print("\nAudio Summary Statistics Table:")
    print(summary_df)

audio_summary_statistics(audio_directory)
# Out:
# <ipython-input-84-a5d8946a040e>:23: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(file_path, sr=None)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Error processing /content/drive/MyDrive/DS4420_Project/data/GTZAN/genres_original/jazz/jazz.00054.wav:
#
# Audio Summary Statistics Table:
#      Genre         Filename  Duration (s)  Sampling Rate  Mean Amplitude  \
# 0    blues  blues.00070.wav     30.013333          22050        0.084276
# 1    blues  blues.00066.wav     30.013333          22050        0.088565
# 2    blues  blues.00029.wav     30.013333          22050        0.100972
# 3    blues  blues.00010.wav     30.013333          22050        0.114130
# 4    blues  blues.00028.wav     30.013333          22050        0.079170
# ..     ...              ...           ...            ...             ...
# 994   jazz   jazz.00031.wav     30.013333          22050        0.034432
# 995   jazz   jazz.00081.wav     30.013333          22050        0.034261
# 996   jazz   jazz.00007.wav     30.013333          22050        0.077327
# 997   jazz   jazz.00060.wav     30.013333          22050        0.085595
# 998   jazz   jazz.00076.wav     30.013333          22050        0.093957
#
#      RMS Amplitude  Max Amplitude
# 0         0.111222       0.671204
# 1         0.113606       0.614380
# 2         0.142754       0.882568
# 3         0.172059       0.901978
# 4         0.118491       0.979095
# ..             ...            ...
# 994       0.045487       0.323303
# 995       0.045952       0.457458
# 996       0.105113       0.574005
# 997       0.115961       0.686127
# 998       0.131184       0.809479
#
# [999 rows x 7 columns]

# %%
# Load VGGish model from TensorFlow Hub
vggish_model = hub.load('https://tfhub.dev/google/vggish/1')

# Function to extract VGGish features
def extract_vggish_features(y, sr, file_path):
    try:
        # Resample the audio for VGGish input
        y_resampled = librosa.resample(y, orig_sr=sr, target_sr=16000)

        # Ensure input is in float32 format
        y_resampled = np.array(y_resampled, dtype=np.float32)

        # Convert to tensor for the model
        y_tensor = tf.convert_to_tensor(y_resampled, dtype=tf.float32)

        # Extract features using VGGish model
        vggish_features = vggish_model(y_tensor)

        if isinstance(vggish_features, tf.Tensor):
            vggish_features = vggish_features.numpy()

        # Flatten the features to use in ML models
        vggish_features_flattened = vggish_features.flatten()
    except Exception as e:
        print(f"Error extracting VGGish features from {file_path}: {e}")
        vggish_features_flattened = None

    return vggish_features_flattened

# Function to extract features from audio files
def extract_features(file_path, sr=22050, n_mels=128, wavelet='db1', n_mfcc=40, n_chroma=24, hop_length=256):
    try:
        # Load audio file
        y, sr = librosa.load(file_path, sr=sr)
        y = np.array(y, dtype=np.float32)

        # Extract Mel spectrogram
        mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=n_mels)
        mel_spectrogram_db = librosa.power_to_db(mel_spectrogram, ref=np.max)
        mel_spectrogram_flattened = mel_spectrogram_db.flatten()  # Flatten for use in ML models

        # Extract wavelet features
        coeffs = pywt.wavedec(y, wavelet, level=5)
        wavelet_features = np.concatenate([np.array(c).flatten() for c in coeffs])

        # Extract MFCC features
        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc, hop_length=hop_length)
        mfcc_flattened = mfcc.flatten()

        # Extract Chroma features
        chroma = librosa.feature.chroma_stft(y=y, sr=sr, n_chroma=n_chroma, hop_length=hop_length)
        chroma_flattened = chroma.flatten()

        # Extract VGGish features
        vggish_features_flattened = extract_vggish_features(y, sr, file_path)

        # Combine all features independently into a dictionary
        features = {
            'mel_spectrogram': mel_spectrogram_flattened,
            'wavelet': wavelet_features,
            'mfcc': mfcc_flattened,
            'chroma': chroma_flattened,
            'vggish': vggish_features_flattened if vggish_features_flattened is not None else np.array([])
        }
    except Exception as e:
        print(f"Error processing audio file {file_path}: {e}")
        features = {
            'mel_spectrogram': np.array([]),
            'wavelet': np.array([]),
            'mfcc': np.array([]),
            'chroma': np.array([]),
            'vggish': np.array([])
        }

    return features

# Function to process the entire dataset and extract features
# and combine them with existing CSV features
def process_dataset(df, audio_directory):
    features = {
        'mel_spectrogram': [],
        'wavelet': [],
        'vggish': [],
        'mfcc': [],
        'chroma': [],
    }
    labels = []

    for idx, row in df.iterrows():
        file_path = os.path.join(audio_directory, row['label'], row['filename'])
        extracted_features = extract_features(file_path)

        # Check if all extracted features are empty
        if all(len(extracted_features[key]) == 0 for key in extracted_features):
            print(f"Skipping row {idx} due to audio extraction issues.")
            continue

        for key in extracted_features:
            features[key].append(extracted_features[key])

        # Add label
        labels.append(row['label'])

    # Convert features lists to NumPy arrays
    for key in features:
        features[key] = np.array(features[key], dtype=object)

    labels = np.array(labels)

    return features, labels

# Function to unify feature lengths based on the maximum length of each feature type
def unify_feature_lengths(features):
    unified_features = {}
    for key in features:
        # Find the maximum length among all samples for each feature type
        max_len = max(len(feature) for feature in features[key])

        # Pad each feature to the maximum length
        padded_features = [np.pad(feature, (0, max_len - len(feature)), 'constant') for feature in features[key]]
        unified_features[key] = np.array(padded_features, dtype=np.float32)

    return unified_features

# Function to standardize features
def standardize_features(features):
    standardized_features = {}
    scalers = {}

    for key in features:
        standardized_features[key] = []
        scalers[key] = []
        for feature in features[key]:
            feature = feature.reshape(-1, 1)
            scaler = StandardScaler()
            standardized_feature = scaler.fit_transform(feature).flatten()
            standardized_features[key].append(standardized_feature)
            scalers[key].append(scaler)
        standardized_features[key] = np.array(standardized_features[key], dtype=np.float32)

    return standardized_features

# Function to print summary statistics of standardized features
def print_standardized_summary_statistics(features):
    summary_statistics = []

    for feature_name, feature_data in features.items():
        feature_shape = np.array(feature_data).shape

        # Flatten all samples to calculate unified statistics
        flattened_data = np.concatenate([seq.flatten() for seq in feature_data])

        # Calculate statistical metrics
        mean = np.mean(flattened_data)
        std = np.std(flattened_data)
        min_val = np.min(flattened_data)
        max_val = np.max(flattened_data)

        summary_statistics.append({
            'Feature': feature_name,
            'Shape': feature_shape,
            'Mean': mean,
            'Std': std,
            'Min': min_val,
            'Max': max_val
        })

    summary_df = pd.DataFrame(summary_statistics)
    print("\nSummary Statistics Table:")
    print(summary_df)

# Function to plot deep-learning models performance
def plot_model_training(history):
    # Retrieve data from the history object for accuracy and loss
    val_accuracy = history.history.get('val_accuracy')
    val_loss = history.history.get('val_loss')
    accuracy = history.history.get('accuracy')
    loss = history.history.get('loss')

    # Set x-axis as the number of epochs
    epochs = range(1, len(accuracy) + 1)

    # Create a figure with two subplots for accuracy and loss
    plt.figure(figsize=(14, 6))

    # Subplot 1: Validation and Training Accuracy
    plt.subplot(1, 2, 1)
    if val_accuracy:
        plt.plot(epochs, val_accuracy, label='Validation Accuracy', color='b')
    if accuracy:
        plt.plot(epochs, accuracy, label='Training Accuracy', color='g', linestyle='--')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Validation and Training Accuracy Over Epochs')
    plt.legend()

    # Subplot 2: Validation and Training Loss
    plt.subplot(1, 2, 2)
    if val_loss:
        plt.plot(epochs, val_loss, label='Validation Loss', color='r')
    if loss:
        plt.plot(epochs, loss, label='Training Loss', color='orange', linestyle='--')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Validation and Training Loss Over Epochs')
    plt.legend()

    # Show the plots
    plt.tight_layout()
    plt.show()

def plot_prediction_heatmap(model, test_features, test_labels, label_encoder, title="Prediction Heatmap"):
    predictions = model.model.predict(test_features)
    # If the output is probability distributions (softmax), use np.argmax to get predicted labels
    if predictions.ndim > 1 and predictions.shape[1] > 1:
        predicted_labels = np.argmax(predictions, axis=1)
    else:
        predicted_labels = (predictions > 0.5).astype(int).flatten()  # For binary classification

    # Inverse transform the numerical labels to get original class labels
    true_labels_decoded = label_encoder.inverse_transform(test_labels)
    predicted_labels_decoded = label_encoder.inverse_transform(predicted_labels)

    # Create the confusion matrix
    conf_matrix = confusion_matrix(true_labels_decoded, predicted_labels_decoded, labels=label_encoder.classes_)

    # Plot the heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title(title)
    plt.show()

# %%
# Extract features from audio directory
features, labels = process_dataset(df_30_sec, audio_directory)

# Unify and standardize features
features = unify_feature_lengths(features)
features = standardize_features(features)

# Generate the summary statistics report for standardized features
print_standardized_summary_statistics(features)

# Split dataset into training, validation, and test sets
train_features = {}
val_features = {}
test_features = {}
# Create a combined list of feature dictionaries and labels for consistent splitting
combined_data = list(zip([{key: features[key][i] for key in features} for i in range(len(labels))], labels))

# Split combined data
train_data, test_data = train_test_split(combined_data, test_size=0.2, random_state=42, stratify=labels)
train_data, val_data = train_test_split(train_data, test_size=0.25, random_state=42, stratify=[label for _, label in train_data])

# Separate features and labels after splitting
for key in features:
    train_features[key] = [data[0][key] for data in train_data]
    val_features[key] = [data[0][key] for data in val_data]
    test_features[key] = [data[0][key] for data in test_data]

train_labels = np.array([data[1] for data in train_data])
val_labels = np.array([data[1] for data in val_data])
test_labels = np.array([data[1] for data in test_data])

# Encode labels as integers
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)

# Save the original category labels
class_names = label_encoder.classes_

train_labels = label_encoder.transform(train_labels)
val_labels = label_encoder.transform(val_labels)
test_labels = label_encoder.transform(test_labels)
num_classes = len(set(labels))

# Pad features again to decrease the length for CUDNN
lengths = [len(seq) for feature in train_features.values() for seq in feature]
max_len = min(15000, int(np.percentile(lengths, 70)))
padded_train_features = {key+'_input': pad_sequences(train_features[key], maxlen=max_len, padding='post', truncating='post', dtype='float32') for key in train_features}
padded_val_features = {key+'_input': pad_sequences(val_features[key], maxlen=max_len, padding='post', truncating='post', dtype='float32') for key in val_features}
padded_test_features = {key+'_input': pad_sequences(test_features[key], maxlen=max_len, padding='post', truncating='post', dtype='float32') for key in test_features}

for key in padded_train_features:
    padded_train_features[key] = np.expand_dims(padded_train_features[key], axis=-1)
    padded_val_features[key] = np.expand_dims(padded_val_features[key], axis=-1)
    padded_test_features[key] = np.expand_dims(padded_test_features[key], axis=-1)
# Out:
# <ipython-input-151-eeb2b31de238>:34: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(file_path, sr=sr)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Error processing audio file /content/drive/MyDrive/DS4420_Project/data/GTZAN/genres_original/jazz/jazz.00054.wav:
# Skipping row 554 due to audio extraction issues.
#
# Summary Statistics Table:
#            Feature          Shape          Mean       Std        Min  \
# 0  mel_spectrogram  (999, 168960) -1.495585e-09  1.000001  -5.203684
# 1          wavelet  (999, 675808)  2.918025e-12  0.999994 -57.596069
# 2           vggish    (999, 3968) -2.781127e-10  1.000000  -6.203063
# 3             mfcc  (999, 105600)  8.562732e-11  0.999999 -22.557358
# 4           chroma   (999, 63360) -3.741374e-10  1.000000  -2.410709
#
#          Max
# 0   4.076281
# 1  56.825695
# 2   9.268440
# 3  10.307214
# 4   3.719159

# %% [markdown]
# # Set up for Deep-Learning Models

# %%
# Set random seeds for reproducibility
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'

# %% [markdown]
# # Deep-Learning: CNNs

# %%
class MusicGenreCNNModel:
    def __init__(self, input_shapes, num_classes, lr_max=1e-2, lr_min=1e-6, warmup_epochs=10, epochs=250, batch_size=64):
        self.input_shapes = input_shapes
        self.num_classes = num_classes
        self.lr_max = lr_max
        self.lr_min = lr_min
        self.warmup_epochs = warmup_epochs
        self.epochs = epochs
        self.batch_size = batch_size
        self.model = None
        self.optimizer = None
        self.lr_callback = None
        self.history = None

        # Set mixed precision policy
        self.policy = tf.keras.mixed_precision.set_global_policy('float32')

        # Create and compile the model
        self._initialize_model()

    def _initialize_model(self):
        """Initialize and compile the CNN model."""
        # Define the optimizer
        self.optimizer = Adam(learning_rate=self.lr_max)

        # Set the learning rate scheduler callback with cosine annealing and warm-up
        T_max = self.epochs - self.warmup_epochs
        self.lr_callback = LearningRateScheduler(lambda epoch: self.combined_lr_schedule(epoch, self.lr_max, self.lr_min, self.warmup_epochs, T_max))

        # Create the CNN model
        self.model = self._create_cnn_model(self.input_shapes, self.num_classes)

        # Compile the model
        self.model.compile(optimizer=self.optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
        self.model.summary()

    def _create_cnn_model(self, input_shapes, num_classes):
        """Create the CNN model for music genre classification."""
        inputs = []
        processed_features = []

        for key, shape in input_shapes.items():
            input_layer = layers.Input(shape=(None, 1), name=f"{key}_input")
            inputs.append(input_layer)

            if key == 'mel_spectrogram' or key == 'chroma':
                # Use Conv2D for Mel spectrogram and Chroma with Global Average Pooling
                time_dimension = layers.Lambda(lambda x: tf.shape(x)[1] // 128)(input_layer)
                padded_input = layers.Lambda(lambda x: tf.pad(x, [[0, 0], [0, 128 - tf.shape(x)[1] % 128], [0, 0]]))(input_layer)
                reshaped_input = layers.Reshape((-1, 128, 1))(padded_input)
                x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(reshaped_input)
                x = layers.BatchNormalization()(x)
                x = layers.SpatialDropout2D(0.2)(x)
                residual = x
                residual = layers.Conv2D(32, (1, 1), padding='same')(residual)
                x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
                x = layers.BatchNormalization()(x)
                x = layers.SpatialDropout2D(0.2)(x)
                x = layers.Add()([x, residual])
                x = layers.MaxPooling2D((2, 2))(x)
                x = layers.GlobalAveragePooling2D()(x)
            processed_features.append(x)

        combined = layers.concatenate(processed_features)
        x = layers.Dense(64, activation='relu')(combined)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(0.3)(x)
        output_layer = layers.Dense(num_classes, activation='softmax')(x)

        return models.Model(inputs=inputs, outputs=output_layer)

    def combined_lr_schedule(self, epoch, lr_max, lr_min, warmup_epochs, T_max):
        """Combined warm-up and cosine annealing learning rate schedule."""
        if epoch < warmup_epochs:
            # Warm-up phase: gradually increase learning rate
            return lr_min + (lr_max - lr_min) * (epoch / warmup_epochs)
        else:
            # Cosine annealing phase after warm-up
            return lr_min + (lr_max - lr_min) * (1 + math.cos((epoch - warmup_epochs) * math.pi / T_max)) / 2

    def train(self, train_features, train_labels, val_features, val_labels):
        """Train the model."""
        self.history = self.model.fit(
            train_features,
            train_labels.astype('int32'),
            validation_data=(val_features, val_labels.astype('int32')),
            epochs=self.epochs,
            batch_size=self.batch_size,
            callbacks=[self.lr_callback]
        )

    def evaluate(self, test_features, test_labels):
        """Evaluate the model on the test set."""
        test_loss, test_accuracy = self.model.evaluate(
            test_features,
            test_labels.astype('int32')
        )
        print(f"Test Loss: {test_loss}")
        print(f"Test Accuracy: {test_accuracy}")

    def predict(self, test_features, test_labels):
        """Make predictions on the test set."""
        predictions = self.model.predict(test_features)
        predicted_labels = np.argmax(predictions, axis=1)
        print(f"Predicted Labels: {predicted_labels}")
        print(f"True Labels: {test_labels.astype('int32')}")

# Define input shapes for CNNs
input_shapes_cnn = {
    'mel_spectrogram': (None, 1),
    'chroma': (None, 1),
}


# Create and train the CNN model
music_genre_cnn_model = MusicGenreCNNModel(input_shapes_cnn, num_classes)
music_genre_cnn_model.train(padded_train_features, train_labels, padded_val_features, val_labels)
music_genre_cnn_model.evaluate(padded_test_features, test_labels)
music_genre_cnn_model.predict(padded_test_features, test_labels)
# Out:
# Model: "functional_28"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ mel_spectrogram_input     │ (None, None, 1)        │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ chroma_input (InputLayer) │ (None, None, 1)        │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_73 (Lambda)        │ (None, None, 1)        │              0 │ mel_spectrogram_input… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_75 (Lambda)        │ (None, None, 1)        │              0 │ chroma_input[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_36 (Reshape)      │ (None, None, 128, 1)   │              0 │ lambda_73[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_37 (Reshape)      │ (None, None, 128, 1)   │              0 │ lambda_75[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_108 (Conv2D)       │ (None, None, 128, 16)  │            160 │ reshape_36[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_111 (Conv2D)       │ (None, None, 128, 16)  │            160 │ reshape_37[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_122   │ (None, None, 128, 16)  │             64 │ conv2d_108[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_124   │ (None, None, 128, 16)  │             64 │ conv2d_111[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_72      │ (None, None, 128, 16)  │              0 │ batch_normalization_1… │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_74      │ (None, None, 128, 16)  │              0 │ batch_normalization_1… │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_110 (Conv2D)       │ (None, None, 128, 32)  │          4,640 │ spatial_dropout2d_72[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_113 (Conv2D)       │ (None, None, 128, 32)  │          4,640 │ spatial_dropout2d_74[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_123   │ (None, None, 128, 32)  │            128 │ conv2d_110[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_125   │ (None, None, 128, 32)  │            128 │ conv2d_113[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_73      │ (None, None, 128, 32)  │              0 │ batch_normalization_1… │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_109 (Conv2D)       │ (None, None, 128, 32)  │            544 │ spatial_dropout2d_72[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_75      │ (None, None, 128, 32)  │              0 │ batch_normalization_1… │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_112 (Conv2D)       │ (None, None, 128, 32)  │            544 │ spatial_dropout2d_74[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_36 (Add)              │ (None, None, 128, 32)  │              0 │ spatial_dropout2d_73[… │
# │                           │                        │                │ conv2d_109[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_37 (Add)              │ (None, None, 128, 32)  │              0 │ spatial_dropout2d_75[… │
# │                           │                        │                │ conv2d_112[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_36          │ (None, None, 64, 32)   │              0 │ add_36[0][0]           │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_37          │ (None, None, 64, 32)   │              0 │ add_37[0][0]           │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 32)             │              0 │ max_pooling2d_36[0][0] │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 32)             │              0 │ max_pooling2d_37[0][0] │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_28            │ (None, 64)             │              0 │ global_average_poolin… │
# │ (Concatenate)             │                        │                │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_56 (Dense)          │ (None, 64)             │          4,160 │ concatenate_28[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_126   │ (None, 64)             │            256 │ dense_56[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_28 (Dropout)      │ (None, 64)             │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_57 (Dense)          │ (None, 10)             │            650 │ dropout_28[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 16,138 (63.04 KB)
#  Trainable params: 15,818 (61.79 KB)
#  Non-trainable params: 320 (1.25 KB)
# Epoch 1/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 838ms/step - accuracy: 0.0987 - loss: 2.9754 - val_accuracy: 0.0850 - val_loss: 2.3163 - learning_rate: 1.0000e-06
# Epoch 2/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.1272 - loss: 2.7787 - val_accuracy: 0.1100 - val_loss: 2.3019 - learning_rate: 0.0010
# Epoch 3/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.2117 - loss: 2.4398 - val_accuracy: 0.1050 - val_loss: 2.2776 - learning_rate: 0.0020
# Epoch 4/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.2344 - loss: 2.1605 - val_accuracy: 0.1200 - val_loss: 2.2492 - learning_rate: 0.0030
# Epoch 5/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.2723 - loss: 2.0533 - val_accuracy: 0.1050 - val_loss: 2.2430 - learning_rate: 0.0040
# Epoch 6/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3117 - loss: 1.8789 - val_accuracy: 0.1000 - val_loss: 2.2790 - learning_rate: 0.0050
# Epoch 7/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3268 - loss: 1.7665 - val_accuracy: 0.1000 - val_loss: 2.3957 - learning_rate: 0.0060
# Epoch 8/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3413 - loss: 1.7639 - val_accuracy: 0.1000 - val_loss: 2.5868 - learning_rate: 0.0070
# Epoch 9/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3619 - loss: 1.6967 - val_accuracy: 0.1250 - val_loss: 2.7420 - learning_rate: 0.0080
# Epoch 10/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4005 - loss: 1.6368 - val_accuracy: 0.1100 - val_loss: 2.8712 - learning_rate: 0.0090
# Epoch 11/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4219 - loss: 1.6222 - val_accuracy: 0.1100 - val_loss: 2.8350 - learning_rate: 0.0100
# Epoch 12/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4180 - loss: 1.6089 - val_accuracy: 0.1250 - val_loss: 2.9438 - learning_rate: 0.0100
# Epoch 13/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4080 - loss: 1.5657 - val_accuracy: 0.1350 - val_loss: 2.9025 - learning_rate: 0.0100
# Epoch 14/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3962 - loss: 1.5372 - val_accuracy: 0.1650 - val_loss: 2.9294 - learning_rate: 0.0100
# Epoch 15/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4145 - loss: 1.5454 - val_accuracy: 0.1150 - val_loss: 2.8835 - learning_rate: 0.0100
# Epoch 16/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4532 - loss: 1.5174 - val_accuracy: 0.1450 - val_loss: 2.9787 - learning_rate: 0.0100
# Epoch 17/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4194 - loss: 1.5316 - val_accuracy: 0.1750 - val_loss: 2.9478 - learning_rate: 0.0100
# Epoch 18/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4668 - loss: 1.4964 - val_accuracy: 0.1900 - val_loss: 3.2288 - learning_rate: 0.0100
# Epoch 19/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4290 - loss: 1.4731 - val_accuracy: 0.1700 - val_loss: 3.1699 - learning_rate: 0.0100
# Epoch 20/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4612 - loss: 1.4409 - val_accuracy: 0.1400 - val_loss: 3.0321 - learning_rate: 0.0100
# Epoch 21/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4411 - loss: 1.4584 - val_accuracy: 0.1600 - val_loss: 3.3532 - learning_rate: 0.0100
# Epoch 22/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4609 - loss: 1.4739 - val_accuracy: 0.1450 - val_loss: 2.9461 - learning_rate: 0.0099
# Epoch 23/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4463 - loss: 1.4449 - val_accuracy: 0.1550 - val_loss: 3.1859 - learning_rate: 0.0099
# Epoch 24/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4491 - loss: 1.4504 - val_accuracy: 0.2150 - val_loss: 3.0570 - learning_rate: 0.0099
# Epoch 25/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4777 - loss: 1.4191 - val_accuracy: 0.2300 - val_loss: 2.7426 - learning_rate: 0.0099
# Epoch 26/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4886 - loss: 1.4043 - val_accuracy: 0.2400 - val_loss: 2.7275 - learning_rate: 0.0099
# Epoch 27/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5208 - loss: 1.2931 - val_accuracy: 0.2150 - val_loss: 2.6442 - learning_rate: 0.0099
# Epoch 28/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4566 - loss: 1.4375 - val_accuracy: 0.1750 - val_loss: 2.5251 - learning_rate: 0.0099
# Epoch 29/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4985 - loss: 1.3919 - val_accuracy: 0.1750 - val_loss: 2.6986 - learning_rate: 0.0099
# Epoch 30/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5064 - loss: 1.4117 - val_accuracy: 0.2850 - val_loss: 2.4188 - learning_rate: 0.0098
# Epoch 31/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4958 - loss: 1.3835 - val_accuracy: 0.2800 - val_loss: 2.5057 - learning_rate: 0.0098
# Epoch 32/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5192 - loss: 1.3595 - val_accuracy: 0.2600 - val_loss: 2.4817 - learning_rate: 0.0098
# Epoch 33/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5568 - loss: 1.3238 - val_accuracy: 0.2550 - val_loss: 2.2404 - learning_rate: 0.0098
# Epoch 34/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5014 - loss: 1.3363 - val_accuracy: 0.2700 - val_loss: 2.0055 - learning_rate: 0.0098
# Epoch 35/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4887 - loss: 1.3854 - val_accuracy: 0.3150 - val_loss: 2.0020 - learning_rate: 0.0098
# Epoch 36/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5136 - loss: 1.3488 - val_accuracy: 0.2450 - val_loss: 2.5153 - learning_rate: 0.0097
# Epoch 37/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5297 - loss: 1.3147 - val_accuracy: 0.4050 - val_loss: 1.7643 - learning_rate: 0.0097
# Epoch 38/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5094 - loss: 1.3446 - val_accuracy: 0.3350 - val_loss: 1.8996 - learning_rate: 0.0097
# Epoch 39/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4775 - loss: 1.3733 - val_accuracy: 0.3300 - val_loss: 1.9772 - learning_rate: 0.0097
# Epoch 40/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5364 - loss: 1.2584 - val_accuracy: 0.4000 - val_loss: 1.7403 - learning_rate: 0.0096
# Epoch 41/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4933 - loss: 1.3047 - val_accuracy: 0.3400 - val_loss: 1.9278 - learning_rate: 0.0096
# Epoch 42/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5081 - loss: 1.3013 - val_accuracy: 0.3950 - val_loss: 1.8411 - learning_rate: 0.0096
# Epoch 43/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5288 - loss: 1.3143 - val_accuracy: 0.4050 - val_loss: 1.8047 - learning_rate: 0.0096
# Epoch 44/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4953 - loss: 1.3656 - val_accuracy: 0.4800 - val_loss: 1.6597 - learning_rate: 0.0095
# Epoch 45/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5578 - loss: 1.2600 - val_accuracy: 0.3700 - val_loss: 1.8860 - learning_rate: 0.0095
# Epoch 46/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5456 - loss: 1.2930 - val_accuracy: 0.2700 - val_loss: 2.1722 - learning_rate: 0.0095
# Epoch 47/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5173 - loss: 1.2603 - val_accuracy: 0.3650 - val_loss: 1.9497 - learning_rate: 0.0095
# Epoch 48/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5121 - loss: 1.3450 - val_accuracy: 0.3950 - val_loss: 1.7611 - learning_rate: 0.0094
# Epoch 49/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5499 - loss: 1.2764 - val_accuracy: 0.5300 - val_loss: 1.4275 - learning_rate: 0.0094
# Epoch 50/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5568 - loss: 1.2724 - val_accuracy: 0.5000 - val_loss: 1.6843 - learning_rate: 0.0094
# Epoch 51/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5117 - loss: 1.3194 - val_accuracy: 0.5300 - val_loss: 1.3583 - learning_rate: 0.0093
# Epoch 52/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5471 - loss: 1.2884 - val_accuracy: 0.4500 - val_loss: 1.6785 - learning_rate: 0.0093
# Epoch 53/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5335 - loss: 1.2283 - val_accuracy: 0.3650 - val_loss: 1.9951 - learning_rate: 0.0093
# Epoch 54/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5773 - loss: 1.2216 - val_accuracy: 0.4000 - val_loss: 1.7739 - learning_rate: 0.0092
# Epoch 55/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5773 - loss: 1.2578 - val_accuracy: 0.5550 - val_loss: 1.4380 - learning_rate: 0.0092
# Epoch 56/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5835 - loss: 1.1762 - val_accuracy: 0.4350 - val_loss: 1.7551 - learning_rate: 0.0092
# Epoch 57/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5580 - loss: 1.2768 - val_accuracy: 0.4300 - val_loss: 1.6000 - learning_rate: 0.0091
# Epoch 58/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5150 - loss: 1.2617 - val_accuracy: 0.5250 - val_loss: 1.4468 - learning_rate: 0.0091
# Epoch 59/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5363 - loss: 1.3121 - val_accuracy: 0.5200 - val_loss: 1.4450 - learning_rate: 0.0090
# Epoch 60/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5166 - loss: 1.2546 - val_accuracy: 0.4800 - val_loss: 1.5342 - learning_rate: 0.0090
# Epoch 61/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5454 - loss: 1.2721 - val_accuracy: 0.4800 - val_loss: 1.5427 - learning_rate: 0.0090
# Epoch 62/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5259 - loss: 1.2454 - val_accuracy: 0.5550 - val_loss: 1.2898 - learning_rate: 0.0089
# Epoch 63/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5534 - loss: 1.2559 - val_accuracy: 0.4850 - val_loss: 1.5346 - learning_rate: 0.0089
# Epoch 64/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5548 - loss: 1.2200 - val_accuracy: 0.3650 - val_loss: 1.8812 - learning_rate: 0.0088
# Epoch 65/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5556 - loss: 1.2094 - val_accuracy: 0.4000 - val_loss: 1.8629 - learning_rate: 0.0088
# Epoch 66/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5192 - loss: 1.2316 - val_accuracy: 0.4200 - val_loss: 1.7666 - learning_rate: 0.0088
# Epoch 67/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5765 - loss: 1.2294 - val_accuracy: 0.4150 - val_loss: 1.9755 - learning_rate: 0.0087
# Epoch 68/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5513 - loss: 1.2317 - val_accuracy: 0.5250 - val_loss: 1.3980 - learning_rate: 0.0087
# Epoch 69/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5620 - loss: 1.2199 - val_accuracy: 0.5050 - val_loss: 1.4655 - learning_rate: 0.0086
# Epoch 70/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5908 - loss: 1.1866 - val_accuracy: 0.5300 - val_loss: 1.3914 - learning_rate: 0.0086
# Epoch 71/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5626 - loss: 1.1791 - val_accuracy: 0.5950 - val_loss: 1.3676 - learning_rate: 0.0085
# Epoch 72/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5630 - loss: 1.1811 - val_accuracy: 0.4600 - val_loss: 1.6620 - learning_rate: 0.0085
# Epoch 73/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5686 - loss: 1.2084 - val_accuracy: 0.5150 - val_loss: 1.4674 - learning_rate: 0.0084
# Epoch 74/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5442 - loss: 1.2058 - val_accuracy: 0.5350 - val_loss: 1.5194 - learning_rate: 0.0084
# Epoch 75/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5881 - loss: 1.1188 - val_accuracy: 0.5150 - val_loss: 1.5831 - learning_rate: 0.0083
# Epoch 76/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5784 - loss: 1.1543 - val_accuracy: 0.5500 - val_loss: 1.4406 - learning_rate: 0.0083
# Epoch 77/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5422 - loss: 1.2029 - val_accuracy: 0.5900 - val_loss: 1.3489 - learning_rate: 0.0082
# Epoch 78/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5454 - loss: 1.1516 - val_accuracy: 0.5700 - val_loss: 1.3549 - learning_rate: 0.0082
# Epoch 79/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5777 - loss: 1.1420 - val_accuracy: 0.4950 - val_loss: 1.5976 - learning_rate: 0.0081
# Epoch 80/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5315 - loss: 1.2082 - val_accuracy: 0.5700 - val_loss: 1.2998 - learning_rate: 0.0081
# Epoch 81/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5895 - loss: 1.1473 - val_accuracy: 0.4250 - val_loss: 1.7577 - learning_rate: 0.0080
# Epoch 82/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5411 - loss: 1.2011 - val_accuracy: 0.5800 - val_loss: 1.3352 - learning_rate: 0.0080
# Epoch 83/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5523 - loss: 1.1621 - val_accuracy: 0.5800 - val_loss: 1.3307 - learning_rate: 0.0079
# Epoch 84/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5661 - loss: 1.1588 - val_accuracy: 0.5200 - val_loss: 1.3588 - learning_rate: 0.0079
# Epoch 85/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5893 - loss: 1.1209 - val_accuracy: 0.5050 - val_loss: 1.4269 - learning_rate: 0.0078
# Epoch 86/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5499 - loss: 1.1580 - val_accuracy: 0.5650 - val_loss: 1.2943 - learning_rate: 0.0078
# Epoch 87/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6353 - loss: 1.0710 - val_accuracy: 0.4900 - val_loss: 1.3615 - learning_rate: 0.0077
# Epoch 88/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5854 - loss: 1.1446 - val_accuracy: 0.5200 - val_loss: 1.5001 - learning_rate: 0.0077
# Epoch 89/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5799 - loss: 1.1095 - val_accuracy: 0.5800 - val_loss: 1.2717 - learning_rate: 0.0076
# Epoch 90/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5659 - loss: 1.1076 - val_accuracy: 0.5200 - val_loss: 1.3567 - learning_rate: 0.0076
# Epoch 91/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6045 - loss: 1.1041 - val_accuracy: 0.5600 - val_loss: 1.3709 - learning_rate: 0.0075
# Epoch 92/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5869 - loss: 1.1564 - val_accuracy: 0.5450 - val_loss: 1.5251 - learning_rate: 0.0074
# Epoch 93/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5970 - loss: 1.1154 - val_accuracy: 0.5600 - val_loss: 1.3219 - learning_rate: 0.0074
# Epoch 94/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5990 - loss: 1.1326 - val_accuracy: 0.5400 - val_loss: 1.4819 - learning_rate: 0.0073
# Epoch 95/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5794 - loss: 1.1027 - val_accuracy: 0.5200 - val_loss: 1.5643 - learning_rate: 0.0073
# Epoch 96/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6069 - loss: 1.0978 - val_accuracy: 0.6000 - val_loss: 1.3000 - learning_rate: 0.0072
# Epoch 97/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5829 - loss: 1.1010 - val_accuracy: 0.6000 - val_loss: 1.3938 - learning_rate: 0.0072
# Epoch 98/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5668 - loss: 1.1434 - val_accuracy: 0.5450 - val_loss: 1.4041 - learning_rate: 0.0071
# Epoch 99/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5982 - loss: 1.1532 - val_accuracy: 0.4850 - val_loss: 1.7044 - learning_rate: 0.0070
# Epoch 100/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5877 - loss: 1.1121 - val_accuracy: 0.5450 - val_loss: 1.4523 - learning_rate: 0.0070
# Epoch 101/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6012 - loss: 1.0638 - val_accuracy: 0.5450 - val_loss: 1.4160 - learning_rate: 0.0069
# Epoch 102/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6125 - loss: 1.0388 - val_accuracy: 0.5600 - val_loss: 1.5415 - learning_rate: 0.0069
# Epoch 103/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6090 - loss: 1.0901 - val_accuracy: 0.5750 - val_loss: 1.2970 - learning_rate: 0.0068
# Epoch 104/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6074 - loss: 1.1142 - val_accuracy: 0.6050 - val_loss: 1.4212 - learning_rate: 0.0067
# Epoch 105/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6095 - loss: 1.1310 - val_accuracy: 0.5250 - val_loss: 1.6218 - learning_rate: 0.0067
# Epoch 106/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6193 - loss: 1.0500 - val_accuracy: 0.5000 - val_loss: 1.5389 - learning_rate: 0.0066
# Epoch 107/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5673 - loss: 1.1214 - val_accuracy: 0.5200 - val_loss: 1.7595 - learning_rate: 0.0065
# Epoch 108/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5860 - loss: 1.1245 - val_accuracy: 0.5200 - val_loss: 1.5289 - learning_rate: 0.0065
# Epoch 109/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6009 - loss: 1.0686 - val_accuracy: 0.5450 - val_loss: 1.4591 - learning_rate: 0.0064
# Epoch 110/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6222 - loss: 1.0826 - val_accuracy: 0.5950 - val_loss: 1.4027 - learning_rate: 0.0064
# Epoch 111/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6258 - loss: 1.0469 - val_accuracy: 0.6000 - val_loss: 1.3262 - learning_rate: 0.0063
# Epoch 112/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5870 - loss: 1.0919 - val_accuracy: 0.5300 - val_loss: 1.3418 - learning_rate: 0.0062
# Epoch 113/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6217 - loss: 1.0795 - val_accuracy: 0.5150 - val_loss: 1.4281 - learning_rate: 0.0062
# Epoch 114/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5920 - loss: 1.1338 - val_accuracy: 0.5450 - val_loss: 1.2991 - learning_rate: 0.0061
# Epoch 115/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6450 - loss: 1.0563 - val_accuracy: 0.5700 - val_loss: 1.2943 - learning_rate: 0.0060
# Epoch 116/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6189 - loss: 1.0499 - val_accuracy: 0.5550 - val_loss: 1.4362 - learning_rate: 0.0060
# Epoch 117/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6280 - loss: 1.0392 - val_accuracy: 0.5850 - val_loss: 1.2892 - learning_rate: 0.0059
# Epoch 118/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6065 - loss: 1.0717 - val_accuracy: 0.5450 - val_loss: 1.4522 - learning_rate: 0.0058
# Epoch 119/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6499 - loss: 1.0544 - val_accuracy: 0.5950 - val_loss: 1.2470 - learning_rate: 0.0058
# Epoch 120/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6166 - loss: 1.0780 - val_accuracy: 0.5100 - val_loss: 1.4048 - learning_rate: 0.0057
# Epoch 121/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6350 - loss: 1.0136 - val_accuracy: 0.5700 - val_loss: 1.3699 - learning_rate: 0.0057
# Epoch 122/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6395 - loss: 1.0421 - val_accuracy: 0.5650 - val_loss: 1.3208 - learning_rate: 0.0056
# Epoch 123/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6389 - loss: 1.0540 - val_accuracy: 0.6150 - val_loss: 1.3085 - learning_rate: 0.0055
# Epoch 124/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6405 - loss: 0.9738 - val_accuracy: 0.5950 - val_loss: 1.2758 - learning_rate: 0.0055
# Epoch 125/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6322 - loss: 1.0288 - val_accuracy: 0.5400 - val_loss: 1.3328 - learning_rate: 0.0054
# Epoch 126/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6329 - loss: 1.0290 - val_accuracy: 0.6000 - val_loss: 1.3173 - learning_rate: 0.0053
# Epoch 127/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6019 - loss: 1.0394 - val_accuracy: 0.5650 - val_loss: 1.3350 - learning_rate: 0.0053
# Epoch 128/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6442 - loss: 1.0138 - val_accuracy: 0.6000 - val_loss: 1.2584 - learning_rate: 0.0052
# Epoch 129/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6324 - loss: 1.0200 - val_accuracy: 0.5700 - val_loss: 1.3774 - learning_rate: 0.0051
# Epoch 130/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6496 - loss: 1.0140 - val_accuracy: 0.5450 - val_loss: 1.3968 - learning_rate: 0.0051
# Epoch 131/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6546 - loss: 1.0035 - val_accuracy: 0.5500 - val_loss: 1.3026 - learning_rate: 0.0050
# Epoch 132/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6427 - loss: 0.9830 - val_accuracy: 0.6050 - val_loss: 1.2174 - learning_rate: 0.0049
# Epoch 133/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6614 - loss: 1.0140 - val_accuracy: 0.5500 - val_loss: 1.3868 - learning_rate: 0.0049
# Epoch 134/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6406 - loss: 0.9609 - val_accuracy: 0.5600 - val_loss: 1.3885 - learning_rate: 0.0048
# Epoch 135/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6632 - loss: 0.9652 - val_accuracy: 0.5200 - val_loss: 1.5920 - learning_rate: 0.0047
# Epoch 136/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6584 - loss: 0.9979 - val_accuracy: 0.6000 - val_loss: 1.2553 - learning_rate: 0.0047
# Epoch 137/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6681 - loss: 0.9647 - val_accuracy: 0.6050 - val_loss: 1.2406 - learning_rate: 0.0046
# Epoch 138/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6317 - loss: 0.9674 - val_accuracy: 0.5500 - val_loss: 1.3990 - learning_rate: 0.0045
# Epoch 139/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6060 - loss: 1.0412 - val_accuracy: 0.5850 - val_loss: 1.2847 - learning_rate: 0.0045
# Epoch 140/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6287 - loss: 0.9923 - val_accuracy: 0.6150 - val_loss: 1.2942 - learning_rate: 0.0044
# Epoch 141/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6203 - loss: 0.9956 - val_accuracy: 0.5500 - val_loss: 1.4414 - learning_rate: 0.0043
# Epoch 142/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6270 - loss: 0.9723 - val_accuracy: 0.5650 - val_loss: 1.3151 - learning_rate: 0.0043
# Epoch 143/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6642 - loss: 0.9633 - val_accuracy: 0.5450 - val_loss: 1.4199 - learning_rate: 0.0042
# Epoch 144/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6487 - loss: 0.9945 - val_accuracy: 0.5500 - val_loss: 1.3285 - learning_rate: 0.0042
# Epoch 145/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6230 - loss: 1.0188 - val_accuracy: 0.5900 - val_loss: 1.2094 - learning_rate: 0.0041
# Epoch 146/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6430 - loss: 0.9781 - val_accuracy: 0.5900 - val_loss: 1.1979 - learning_rate: 0.0040
# Epoch 147/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6385 - loss: 1.0179 - val_accuracy: 0.5850 - val_loss: 1.2506 - learning_rate: 0.0040
# Epoch 148/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6612 - loss: 1.0007 - val_accuracy: 0.5800 - val_loss: 1.3594 - learning_rate: 0.0039
# Epoch 149/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6656 - loss: 0.9696 - val_accuracy: 0.5500 - val_loss: 1.3508 - learning_rate: 0.0038
# Epoch 150/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6486 - loss: 0.9975 - val_accuracy: 0.6150 - val_loss: 1.2146 - learning_rate: 0.0038
# Epoch 151/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6427 - loss: 0.9839 - val_accuracy: 0.5950 - val_loss: 1.2467 - learning_rate: 0.0037
# Epoch 152/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6710 - loss: 0.9203 - val_accuracy: 0.6150 - val_loss: 1.1894 - learning_rate: 0.0036
# Epoch 153/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6443 - loss: 0.9760 - val_accuracy: 0.6100 - val_loss: 1.2007 - learning_rate: 0.0036
# Epoch 154/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6578 - loss: 0.9375 - val_accuracy: 0.5450 - val_loss: 1.4908 - learning_rate: 0.0035
# Epoch 155/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6509 - loss: 0.9559 - val_accuracy: 0.5400 - val_loss: 1.4520 - learning_rate: 0.0035
# Epoch 156/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6252 - loss: 0.9865 - val_accuracy: 0.5900 - val_loss: 1.3650 - learning_rate: 0.0034
# Epoch 157/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6750 - loss: 0.9018 - val_accuracy: 0.5700 - val_loss: 1.4227 - learning_rate: 0.0033
# Epoch 158/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6558 - loss: 0.9336 - val_accuracy: 0.5150 - val_loss: 1.5156 - learning_rate: 0.0033
# Epoch 159/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6417 - loss: 0.9974 - val_accuracy: 0.5800 - val_loss: 1.3114 - learning_rate: 0.0032
# Epoch 160/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6535 - loss: 0.9571 - val_accuracy: 0.6000 - val_loss: 1.2288 - learning_rate: 0.0031
# Epoch 161/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6477 - loss: 0.9641 - val_accuracy: 0.5750 - val_loss: 1.2711 - learning_rate: 0.0031
# Epoch 162/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6844 - loss: 0.9275 - val_accuracy: 0.5550 - val_loss: 1.4019 - learning_rate: 0.0030
# Epoch 163/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6596 - loss: 0.9115 - val_accuracy: 0.5550 - val_loss: 1.4240 - learning_rate: 0.0030
# Epoch 164/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6688 - loss: 0.9281 - val_accuracy: 0.5700 - val_loss: 1.3922 - learning_rate: 0.0029
# Epoch 165/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6472 - loss: 0.9619 - val_accuracy: 0.5050 - val_loss: 1.5619 - learning_rate: 0.0028
# Epoch 166/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6622 - loss: 0.9338 - val_accuracy: 0.5550 - val_loss: 1.3845 - learning_rate: 0.0028
# Epoch 167/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6493 - loss: 0.9711 - val_accuracy: 0.6100 - val_loss: 1.2910 - learning_rate: 0.0027
# Epoch 168/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6648 - loss: 0.9606 - val_accuracy: 0.6100 - val_loss: 1.2693 - learning_rate: 0.0027
# Epoch 169/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6597 - loss: 0.9591 - val_accuracy: 0.6300 - val_loss: 1.2325 - learning_rate: 0.0026
# Epoch 170/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6619 - loss: 0.9325 - val_accuracy: 0.6250 - val_loss: 1.1744 - learning_rate: 0.0026
# Epoch 171/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6244 - loss: 0.9110 - val_accuracy: 0.6450 - val_loss: 1.1712 - learning_rate: 0.0025
# Epoch 172/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6350 - loss: 0.9263 - val_accuracy: 0.6000 - val_loss: 1.2432 - learning_rate: 0.0024
# Epoch 173/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6872 - loss: 0.8663 - val_accuracy: 0.5800 - val_loss: 1.2862 - learning_rate: 0.0024
# Epoch 174/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6582 - loss: 0.9236 - val_accuracy: 0.6050 - val_loss: 1.2856 - learning_rate: 0.0023
# Epoch 175/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6601 - loss: 0.9227 - val_accuracy: 0.5900 - val_loss: 1.3144 - learning_rate: 0.0023
# Epoch 176/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6600 - loss: 0.9566 - val_accuracy: 0.6000 - val_loss: 1.3390 - learning_rate: 0.0022
# Epoch 177/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6718 - loss: 0.8894 - val_accuracy: 0.6150 - val_loss: 1.2066 - learning_rate: 0.0022
# Epoch 178/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6639 - loss: 0.8879 - val_accuracy: 0.6250 - val_loss: 1.2444 - learning_rate: 0.0021
# Epoch 179/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6675 - loss: 0.9119 - val_accuracy: 0.6050 - val_loss: 1.2604 - learning_rate: 0.0021
# Epoch 180/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6719 - loss: 0.9363 - val_accuracy: 0.5950 - val_loss: 1.2505 - learning_rate: 0.0020
# Epoch 181/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6466 - loss: 0.9160 - val_accuracy: 0.6000 - val_loss: 1.2137 - learning_rate: 0.0020
# Epoch 182/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6648 - loss: 0.9313 - val_accuracy: 0.6450 - val_loss: 1.1980 - learning_rate: 0.0019
# Epoch 183/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6597 - loss: 0.9466 - val_accuracy: 0.5950 - val_loss: 1.2899 - learning_rate: 0.0019
# Epoch 184/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6542 - loss: 0.9212 - val_accuracy: 0.5850 - val_loss: 1.2961 - learning_rate: 0.0018
# Epoch 185/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6626 - loss: 0.8998 - val_accuracy: 0.6000 - val_loss: 1.2447 - learning_rate: 0.0018
# Epoch 186/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6893 - loss: 0.8708 - val_accuracy: 0.6100 - val_loss: 1.2713 - learning_rate: 0.0017
# Epoch 187/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7115 - loss: 0.8498 - val_accuracy: 0.6050 - val_loss: 1.2284 - learning_rate: 0.0017
# Epoch 188/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6955 - loss: 0.8469 - val_accuracy: 0.6150 - val_loss: 1.2140 - learning_rate: 0.0016
# Epoch 189/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6939 - loss: 0.8220 - val_accuracy: 0.6000 - val_loss: 1.2851 - learning_rate: 0.0016
# Epoch 190/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6621 - loss: 0.9218 - val_accuracy: 0.6050 - val_loss: 1.2746 - learning_rate: 0.0015
# Epoch 191/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7166 - loss: 0.8168 - val_accuracy: 0.5750 - val_loss: 1.3202 - learning_rate: 0.0015
# Epoch 192/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6491 - loss: 0.9298 - val_accuracy: 0.5950 - val_loss: 1.2807 - learning_rate: 0.0014
# Epoch 193/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6926 - loss: 0.8422 - val_accuracy: 0.6200 - val_loss: 1.2695 - learning_rate: 0.0014
# Epoch 194/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6979 - loss: 0.8678 - val_accuracy: 0.6300 - val_loss: 1.2223 - learning_rate: 0.0013
# Epoch 195/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6550 - loss: 0.9288 - val_accuracy: 0.6100 - val_loss: 1.2288 - learning_rate: 0.0013
# Epoch 196/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6469 - loss: 0.9175 - val_accuracy: 0.5850 - val_loss: 1.2864 - learning_rate: 0.0012
# Epoch 197/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6465 - loss: 0.9110 - val_accuracy: 0.5850 - val_loss: 1.3130 - learning_rate: 0.0012
# Epoch 198/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7019 - loss: 0.8213 - val_accuracy: 0.5850 - val_loss: 1.3030 - learning_rate: 0.0012
# Epoch 199/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6741 - loss: 0.8890 - val_accuracy: 0.6000 - val_loss: 1.3104 - learning_rate: 0.0011
# Epoch 200/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6773 - loss: 0.8698 - val_accuracy: 0.6000 - val_loss: 1.2827 - learning_rate: 0.0011
# Epoch 201/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7166 - loss: 0.8474 - val_accuracy: 0.6050 - val_loss: 1.2241 - learning_rate: 0.0010
# Epoch 202/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7021 - loss: 0.8639 - val_accuracy: 0.5950 - val_loss: 1.2292 - learning_rate: 9.9463e-04
# Epoch 203/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6837 - loss: 0.8600 - val_accuracy: 0.6100 - val_loss: 1.2216 - learning_rate: 9.5582e-04
# Epoch 204/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6836 - loss: 0.8862 - val_accuracy: 0.6200 - val_loss: 1.1933 - learning_rate: 9.1770e-04
# Epoch 205/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6729 - loss: 0.9188 - val_accuracy: 0.6050 - val_loss: 1.1994 - learning_rate: 8.8028e-04
# Epoch 206/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6835 - loss: 0.8457 - val_accuracy: 0.6050 - val_loss: 1.2001 - learning_rate: 8.4357e-04
# Epoch 207/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6584 - loss: 0.8768 - val_accuracy: 0.5950 - val_loss: 1.2095 - learning_rate: 8.0757e-04
# Epoch 208/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6890 - loss: 0.8720 - val_accuracy: 0.6100 - val_loss: 1.2323 - learning_rate: 7.7228e-04
# Epoch 209/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7096 - loss: 0.8275 - val_accuracy: 0.6000 - val_loss: 1.2398 - learning_rate: 7.3773e-04
# Epoch 210/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6916 - loss: 0.8565 - val_accuracy: 0.5800 - val_loss: 1.2399 - learning_rate: 7.0390e-04
# Epoch 211/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6658 - loss: 0.8547 - val_accuracy: 0.5750 - val_loss: 1.2816 - learning_rate: 6.7081e-04
# Epoch 212/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6826 - loss: 0.8675 - val_accuracy: 0.6000 - val_loss: 1.2879 - learning_rate: 6.3846e-04
# Epoch 213/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7043 - loss: 0.8315 - val_accuracy: 0.6250 - val_loss: 1.2456 - learning_rate: 6.0685e-04
# Epoch 214/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6930 - loss: 0.8636 - val_accuracy: 0.6150 - val_loss: 1.2386 - learning_rate: 5.7600e-04
# Epoch 215/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6650 - loss: 0.8917 - val_accuracy: 0.6150 - val_loss: 1.2349 - learning_rate: 5.4591e-04
# Epoch 216/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6880 - loss: 0.8520 - val_accuracy: 0.5950 - val_loss: 1.2358 - learning_rate: 5.1658e-04
# Epoch 217/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6922 - loss: 0.8862 - val_accuracy: 0.6000 - val_loss: 1.2283 - learning_rate: 4.8802e-04
# Epoch 218/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7254 - loss: 0.7915 - val_accuracy: 0.6150 - val_loss: 1.2184 - learning_rate: 4.6024e-04
# Epoch 219/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6915 - loss: 0.8356 - val_accuracy: 0.6200 - val_loss: 1.2330 - learning_rate: 4.3323e-04
# Epoch 220/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6712 - loss: 0.9090 - val_accuracy: 0.6100 - val_loss: 1.2503 - learning_rate: 4.0700e-04
# Epoch 221/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6811 - loss: 0.8524 - val_accuracy: 0.6050 - val_loss: 1.2532 - learning_rate: 3.8156e-04
# Epoch 222/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6889 - loss: 0.8273 - val_accuracy: 0.6250 - val_loss: 1.2571 - learning_rate: 3.5692e-04
# Epoch 223/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7087 - loss: 0.8102 - val_accuracy: 0.6300 - val_loss: 1.2540 - learning_rate: 3.3306e-04
# Epoch 224/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6867 - loss: 0.8359 - val_accuracy: 0.6250 - val_loss: 1.2373 - learning_rate: 3.1001e-04
# Epoch 225/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6654 - loss: 0.8616 - val_accuracy: 0.6350 - val_loss: 1.2351 - learning_rate: 2.8776e-04
# Epoch 226/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6742 - loss: 0.8650 - val_accuracy: 0.6350 - val_loss: 1.2326 - learning_rate: 2.6632e-04
# Epoch 227/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6917 - loss: 0.8582 - val_accuracy: 0.6450 - val_loss: 1.2225 - learning_rate: 2.4569e-04
# Epoch 228/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6854 - loss: 0.8429 - val_accuracy: 0.6350 - val_loss: 1.2164 - learning_rate: 2.2588e-04
# Epoch 229/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6888 - loss: 0.8527 - val_accuracy: 0.6250 - val_loss: 1.2177 - learning_rate: 2.0688e-04
# Epoch 230/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6691 - loss: 0.8664 - val_accuracy: 0.6250 - val_loss: 1.2227 - learning_rate: 1.8871e-04
# Epoch 231/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7222 - loss: 0.7876 - val_accuracy: 0.6200 - val_loss: 1.2263 - learning_rate: 1.7135e-04
# Epoch 232/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6868 - loss: 0.8391 - val_accuracy: 0.6250 - val_loss: 1.2270 - learning_rate: 1.5483e-04
# Epoch 233/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6835 - loss: 0.8648 - val_accuracy: 0.6300 - val_loss: 1.2295 - learning_rate: 1.3914e-04
# Epoch 234/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6549 - loss: 0.9118 - val_accuracy: 0.6250 - val_loss: 1.2263 - learning_rate: 1.2428e-04
# Epoch 235/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6861 - loss: 0.9191 - val_accuracy: 0.6250 - val_loss: 1.2202 - learning_rate: 1.1025e-04
# Epoch 236/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7032 - loss: 0.8164 - val_accuracy: 0.6200 - val_loss: 1.2136 - learning_rate: 9.7064e-05
# Epoch 237/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6916 - loss: 0.8105 - val_accuracy: 0.6250 - val_loss: 1.2059 - learning_rate: 8.4717e-05
# Epoch 238/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6768 - loss: 0.8467 - val_accuracy: 0.6250 - val_loss: 1.2024 - learning_rate: 7.3212e-05
# Epoch 239/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6982 - loss: 0.8429 - val_accuracy: 0.6300 - val_loss: 1.2024 - learning_rate: 6.2552e-05
# Epoch 240/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6657 - loss: 0.8748 - val_accuracy: 0.6300 - val_loss: 1.2030 - learning_rate: 5.2738e-05
# Epoch 241/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6821 - loss: 0.8254 - val_accuracy: 0.6250 - val_loss: 1.2062 - learning_rate: 4.3771e-05
# Epoch 242/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6663 - loss: 0.9194 - val_accuracy: 0.6300 - val_loss: 1.2064 - learning_rate: 3.5654e-05
# Epoch 243/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6598 - loss: 0.8831 - val_accuracy: 0.6250 - val_loss: 1.2058 - learning_rate: 2.8388e-05
# Epoch 244/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7067 - loss: 0.7895 - val_accuracy: 0.6250 - val_loss: 1.2045 - learning_rate: 2.1973e-05
# Epoch 245/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6980 - loss: 0.8232 - val_accuracy: 0.6250 - val_loss: 1.2044 - learning_rate: 1.6412e-05
# Epoch 246/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6848 - loss: 0.8359 - val_accuracy: 0.6200 - val_loss: 1.2033 - learning_rate: 1.1704e-05
# Epoch 247/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6777 - loss: 0.8715 - val_accuracy: 0.6250 - val_loss: 1.2028 - learning_rate: 7.8516e-06
# Epoch 248/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6759 - loss: 0.8830 - val_accuracy: 0.6250 - val_loss: 1.2031 - learning_rate: 4.8544e-06
# Epoch 249/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6903 - loss: 0.8537 - val_accuracy: 0.6250 - val_loss: 1.2015 - learning_rate: 2.7132e-06
# Epoch 250/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6815 - loss: 0.8391 - val_accuracy: 0.6250 - val_loss: 1.2025 - learning_rate: 1.4283e-06
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6339 - loss: 1.3785
# Test Loss: 1.4297232627868652
# Test Accuracy: 0.625
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step
# Predicted Labels: [1 9 6 5 9 2 9 2 3 5 0 0 8 0 9 4 8 1 2 7 0 6 0 2 0 1 7 4 5 2 6 0 5 4 1 6 9
#  4 2 0 8 5 2 9 5 5 6 1 4 4 0 6 4 5 8 3 8 1 1 9 4 6 8 9 6 0 5 1 2 0 6 0 1 7
#  8 4 3 7 7 2 3 7 4 4 5 2 4 4 2 0 6 8 6 3 3 2 5 5 0 8 8 6 8 2 6 5 7 4 9 3 0
#  9 1 2 1 9 1 9 8 2 1 3 5 6 5 1 6 4 6 3 6 6 7 5 2 2 3 2 4 8 5 4 3 9 2 4 4 0
#  1 4 7 1 1 0 9 8 6 0 1 2 4 3 4 5 6 9 4 2 2 0 6 2 0 2 2 1 8 7 2 3 6 4 1 4 1
#  3 6 0 9 2 4 1 4 3 4 2 2 1 2 2]
# True Labels: [1 0 6 5 0 2 9 2 4 5 0 0 8 0 9 3 8 5 3 9 2 6 0 2 0 1 7 8 5 5 6 2 5 4 1 6 9
#  4 2 3 8 9 7 0 5 5 6 1 4 7 4 6 4 5 8 3 3 1 1 8 6 8 8 9 3 9 9 1 9 7 6 8 1 7
#  8 4 3 7 7 7 3 7 8 4 5 9 8 4 9 5 6 8 6 3 2 5 5 2 8 8 6 0 8 7 6 9 3 3 6 3 0
#  0 1 2 1 2 1 9 8 7 3 0 5 9 8 1 6 4 6 3 6 4 7 5 7 2 3 2 3 8 5 0 3 0 2 4 4 0
#  1 4 7 1 1 0 9 0 6 5 1 0 3 3 4 5 8 9 9 2 7 0 6 5 0 9 7 1 7 4 2 3 6 4 9 4 1
#  7 6 2 5 2 4 1 7 7 4 2 2 1 9 2]

# %%
plot_model_training(music_genre_cnn_model.history)
plot_prediction_heatmap(music_genre_cnn_model, padded_test_features, test_labels, label_encoder)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# # Deep-Learning: RNNs

# %%
class MusicGenreRNNModel:
    def __init__(self, input_shapes, num_classes, lr_max=1e-3, lr_min=1e-6, warmup_epochs=10, epochs=200, batch_size=64):
        self.input_shapes = input_shapes
        self.num_classes = num_classes
        self.lr_max = lr_max
        self.lr_min = lr_min
        self.warmup_epochs = warmup_epochs
        self.epochs = epochs
        self.batch_size = batch_size
        self.model = None
        self.optimizer = None
        self.lr_callback = None
        self.history = None
        self.policy = tf.keras.mixed_precision.set_global_policy('float32')
        self._initialize_model()

    def _initialize_model(self):
        """Initialize and compile the RNN model."""
        self.optimizer = Adam(learning_rate=self.lr_max)

        T_max = self.epochs - self.warmup_epochs
        self.lr_callback = LearningRateScheduler(lambda epoch: self.combined_lr_schedule(epoch, self.lr_max, self.lr_min, self.warmup_epochs, T_max))

        # Create the RNN model
        self.model = self._create_rnn_model(self.input_shapes, self.num_classes)

        self.model.compile(optimizer=self.optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
        self.model.summary()

    def _create_rnn_model(self, input_shapes, num_classes):
        """Create the RNN model for music genre classification."""
        inputs = []
        processed_features = []

        for key, shape in input_shapes.items():
            input_layer = layers.Input(shape=(None, 1), name=f"{key}_input")
            inputs.append(input_layer)

            if key == 'wavelet' or key == 'mfcc':
                # Use Bidirectional LSTM for wavelet and mfcc features
                x = layers.Bidirectional(layers.LSTM(32, return_sequences=True))(input_layer)
                x = layers.BatchNormalization()(x)
                x = layers.SpatialDropout1D(0.3)(x)
                x = layers.GlobalAveragePooling1D()(x)
            processed_features.append(x)

        combined = layers.concatenate(processed_features)
        x = layers.Dense(128, activation='relu')(combined)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(0.4)(x)
        output_layer = layers.Dense(num_classes, activation='softmax')(x)

        return models.Model(inputs=inputs, outputs=output_layer)

    def combined_lr_schedule(self, epoch, lr_max, lr_min, warmup_epochs, T_max):
        """Combined warm-up and cosine annealing learning rate schedule."""
        if epoch < warmup_epochs:
            return lr_min + (lr_max - lr_min) * (epoch / warmup_epochs)
        else:
            return lr_min + (lr_max - lr_min) * (1 + math.cos((epoch - warmup_epochs) * math.pi / T_max)) / 2

    def train(self, train_features, train_labels, val_features, val_labels):
        """Train the model."""
        self.history = self.model.fit(
            train_features,
            train_labels.astype('int32'),
            validation_data=(val_features, val_labels.astype('int32')),
            epochs=self.epochs,
            batch_size=self.batch_size,
            callbacks=[self.lr_callback]
        )

    def evaluate(self, test_features, test_labels):
        """Evaluate the model on the test set."""
        test_loss, test_accuracy = self.model.evaluate(
            test_features,
            test_labels.astype('int32')
        )
        print(f"Test Loss: {test_loss}")
        print(f"Test Accuracy: {test_accuracy}")

    def predict(self, test_features, test_labels):
        """Make predictions on the test set."""
        predictions = self.model.predict(test_features)
        predicted_labels = np.argmax(predictions, axis=1)
        print(f"Predicted Labels: {predicted_labels}")
        print(f"True Labels: {test_labels.astype('int32')}")

# Define input shapes for RNNs
input_shapes_rnn = {
    'wavelet': (None, 1),
    'mfcc': (None, 1),
}

# Create and train the RNN model
music_genre_rnn_model = MusicGenreRNNModel(input_shapes_rnn, num_classes)
music_genre_rnn_model.train(padded_train_features, train_labels, padded_val_features, val_labels)
music_genre_rnn_model.evaluate(padded_test_features, test_labels)
music_genre_rnn_model.predict(padded_test_features, test_labels)
# Out:
# Model: "functional_29"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ wavelet_input             │ (None, None, 1)        │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ mfcc_input (InputLayer)   │ (None, None, 1)        │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bidirectional_22          │ (None, None, 64)       │          8,704 │ wavelet_input[0][0]    │
# │ (Bidirectional)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bidirectional_23          │ (None, None, 64)       │          8,704 │ mfcc_input[0][0]       │
# │ (Bidirectional)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_127   │ (None, None, 64)       │            256 │ bidirectional_22[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_128   │ (None, None, 64)       │            256 │ bidirectional_23[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout1d_22      │ (None, None, 64)       │              0 │ batch_normalization_1… │
# │ (SpatialDropout1D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout1d_23      │ (None, None, 64)       │              0 │ batch_normalization_1… │
# │ (SpatialDropout1D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling1d… │ (None, 64)             │              0 │ spatial_dropout1d_22[… │
# │ (GlobalAveragePooling1D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling1d… │ (None, 64)             │              0 │ spatial_dropout1d_23[… │
# │ (GlobalAveragePooling1D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_29            │ (None, 128)            │              0 │ global_average_poolin… │
# │ (Concatenate)             │                        │                │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_58 (Dense)          │ (None, 128)            │         16,512 │ concatenate_29[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_129   │ (None, 128)            │            512 │ dense_58[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_29 (Dropout)      │ (None, 128)            │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_59 (Dense)          │ (None, 10)             │          1,290 │ dropout_29[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 36,234 (141.54 KB)
#  Trainable params: 35,722 (139.54 KB)
#  Non-trainable params: 512 (2.00 KB)
# Epoch 1/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.1266 - loss: 3.0804 - val_accuracy: 0.0850 - val_loss: 2.2975 - learning_rate: 1.0000e-06
# Epoch 2/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.1000 - loss: 3.2209 - val_accuracy: 0.0850 - val_loss: 2.2958 - learning_rate: 1.0090e-04
# Epoch 3/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.1398 - loss: 3.1093 - val_accuracy: 0.0900 - val_loss: 2.2937 - learning_rate: 2.0080e-04
# Epoch 4/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.1273 - loss: 2.9146 - val_accuracy: 0.1250 - val_loss: 2.2917 - learning_rate: 3.0070e-04
# Epoch 5/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.1646 - loss: 2.8000 - val_accuracy: 0.1000 - val_loss: 2.2900 - learning_rate: 4.0060e-04
# Epoch 6/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.1559 - loss: 2.7430 - val_accuracy: 0.1100 - val_loss: 2.2884 - learning_rate: 5.0050e-04
# Epoch 7/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.1987 - loss: 2.6255 - val_accuracy: 0.1300 - val_loss: 2.2865 - learning_rate: 6.0040e-04
# Epoch 8/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.1808 - loss: 2.6107 - val_accuracy: 0.1650 - val_loss: 2.2855 - learning_rate: 7.0030e-04
# Epoch 9/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.2330 - loss: 2.4774 - val_accuracy: 0.1350 - val_loss: 2.2827 - learning_rate: 8.0020e-04
# Epoch 10/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.2207 - loss: 2.3662 - val_accuracy: 0.1300 - val_loss: 2.2755 - learning_rate: 9.0010e-04
# Epoch 11/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.2424 - loss: 2.3771 - val_accuracy: 0.1600 - val_loss: 2.2644 - learning_rate: 0.0010
# Epoch 12/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.3128 - loss: 2.2192 - val_accuracy: 0.1600 - val_loss: 2.2580 - learning_rate: 9.9993e-04
# Epoch 13/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.2934 - loss: 2.1812 - val_accuracy: 0.1550 - val_loss: 2.2469 - learning_rate: 9.9973e-04
# Epoch 14/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.2951 - loss: 2.0924 - val_accuracy: 0.1500 - val_loss: 2.2276 - learning_rate: 9.9939e-04
# Epoch 15/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.2982 - loss: 2.0896 - val_accuracy: 0.1900 - val_loss: 2.2022 - learning_rate: 9.9891e-04
# Epoch 16/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.3398 - loss: 1.9240 - val_accuracy: 0.1650 - val_loss: 2.2019 - learning_rate: 9.9829e-04
# Epoch 17/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.3812 - loss: 1.8010 - val_accuracy: 0.1850 - val_loss: 2.1618 - learning_rate: 9.9754e-04
# Epoch 18/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.3493 - loss: 1.9163 - val_accuracy: 0.2350 - val_loss: 2.1710 - learning_rate: 9.9666e-04
# Epoch 19/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.3863 - loss: 1.8273 - val_accuracy: 0.2050 - val_loss: 2.1401 - learning_rate: 9.9564e-04
# Epoch 20/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.3959 - loss: 1.7458 - val_accuracy: 0.1850 - val_loss: 2.1748 - learning_rate: 9.9448e-04
# Epoch 21/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.3155 - loss: 1.8735 - val_accuracy: 0.1950 - val_loss: 2.0809 - learning_rate: 9.9319e-04
# Epoch 22/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.3787 - loss: 1.7791 - val_accuracy: 0.1900 - val_loss: 2.0764 - learning_rate: 9.9176e-04
# Epoch 23/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4055 - loss: 1.7211 - val_accuracy: 0.2100 - val_loss: 2.0273 - learning_rate: 9.9020e-04
# Epoch 24/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.3861 - loss: 1.6854 - val_accuracy: 0.1750 - val_loss: 2.0519 - learning_rate: 9.8850e-04
# Epoch 25/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.3893 - loss: 1.7108 - val_accuracy: 0.2500 - val_loss: 2.0271 - learning_rate: 9.8668e-04
# Epoch 26/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4075 - loss: 1.6657 - val_accuracy: 0.2150 - val_loss: 2.0149 - learning_rate: 9.8472e-04
# Epoch 27/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4015 - loss: 1.6717 - val_accuracy: 0.2400 - val_loss: 1.9925 - learning_rate: 9.8262e-04
# Epoch 28/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4053 - loss: 1.6388 - val_accuracy: 0.2000 - val_loss: 2.0426 - learning_rate: 9.8040e-04
# Epoch 29/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4220 - loss: 1.6075 - val_accuracy: 0.2250 - val_loss: 2.0094 - learning_rate: 9.7804e-04
# Epoch 30/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4078 - loss: 1.6825 - val_accuracy: 0.2900 - val_loss: 1.9006 - learning_rate: 9.7555e-04
# Epoch 31/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.3972 - loss: 1.5976 - val_accuracy: 0.3150 - val_loss: 1.8963 - learning_rate: 9.7294e-04
# Epoch 32/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4253 - loss: 1.5654 - val_accuracy: 0.3050 - val_loss: 1.8852 - learning_rate: 9.7019e-04
# Epoch 33/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4178 - loss: 1.5673 - val_accuracy: 0.2800 - val_loss: 1.8625 - learning_rate: 9.6731e-04
# Epoch 34/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4400 - loss: 1.5255 - val_accuracy: 0.3650 - val_loss: 1.7859 - learning_rate: 9.6431e-04
# Epoch 35/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4270 - loss: 1.5516 - val_accuracy: 0.3300 - val_loss: 1.8110 - learning_rate: 9.6118e-04
# Epoch 36/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4762 - loss: 1.5022 - val_accuracy: 0.3650 - val_loss: 1.7284 - learning_rate: 9.5793e-04
# Epoch 37/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4583 - loss: 1.4654 - val_accuracy: 0.3400 - val_loss: 1.8505 - learning_rate: 9.5455e-04
# Epoch 38/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4814 - loss: 1.4692 - val_accuracy: 0.2800 - val_loss: 1.8082 - learning_rate: 9.5104e-04
# Epoch 39/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4437 - loss: 1.4836 - val_accuracy: 0.4050 - val_loss: 1.6318 - learning_rate: 9.4742e-04
# Epoch 40/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4521 - loss: 1.4896 - val_accuracy: 0.3250 - val_loss: 1.7103 - learning_rate: 9.4367e-04
# Epoch 41/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4541 - loss: 1.4872 - val_accuracy: 0.2950 - val_loss: 2.0912 - learning_rate: 9.3980e-04
# Epoch 42/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4438 - loss: 1.4456 - val_accuracy: 0.3250 - val_loss: 1.8908 - learning_rate: 9.3581e-04
# Epoch 43/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4600 - loss: 1.5057 - val_accuracy: 0.4800 - val_loss: 1.5999 - learning_rate: 9.3170e-04
# Epoch 44/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5428 - loss: 1.3971 - val_accuracy: 0.4800 - val_loss: 1.4927 - learning_rate: 9.2747e-04
# Epoch 45/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4718 - loss: 1.4036 - val_accuracy: 0.4700 - val_loss: 1.4955 - learning_rate: 9.2312e-04
# Epoch 46/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4660 - loss: 1.4363 - val_accuracy: 0.3750 - val_loss: 1.5924 - learning_rate: 9.1866e-04
# Epoch 47/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4947 - loss: 1.3298 - val_accuracy: 0.4050 - val_loss: 1.5965 - learning_rate: 9.1409e-04
# Epoch 48/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5143 - loss: 1.3787 - val_accuracy: 0.4300 - val_loss: 1.5441 - learning_rate: 9.0940e-04
# Epoch 49/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5131 - loss: 1.3531 - val_accuracy: 0.3650 - val_loss: 1.9042 - learning_rate: 9.0460e-04
# Epoch 50/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5027 - loss: 1.3865 - val_accuracy: 0.4500 - val_loss: 1.5117 - learning_rate: 8.9969e-04
# Epoch 51/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4921 - loss: 1.3495 - val_accuracy: 0.3750 - val_loss: 1.8137 - learning_rate: 8.9468e-04
# Epoch 52/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5204 - loss: 1.3493 - val_accuracy: 0.3400 - val_loss: 1.9399 - learning_rate: 8.8955e-04
# Epoch 53/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5374 - loss: 1.3856 - val_accuracy: 0.3500 - val_loss: 2.1106 - learning_rate: 8.8432e-04
# Epoch 54/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4967 - loss: 1.3756 - val_accuracy: 0.4000 - val_loss: 1.6992 - learning_rate: 8.7898e-04
# Epoch 55/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5173 - loss: 1.3412 - val_accuracy: 0.4250 - val_loss: 1.5545 - learning_rate: 8.7354e-04
# Epoch 56/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5610 - loss: 1.2485 - val_accuracy: 0.4050 - val_loss: 1.6979 - learning_rate: 8.6799e-04
# Epoch 57/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5238 - loss: 1.3498 - val_accuracy: 0.4250 - val_loss: 1.5162 - learning_rate: 8.6235e-04
# Epoch 58/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5049 - loss: 1.3370 - val_accuracy: 0.3850 - val_loss: 2.1064 - learning_rate: 8.5661e-04
# Epoch 59/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5122 - loss: 1.3035 - val_accuracy: 0.3500 - val_loss: 1.6601 - learning_rate: 8.5077e-04
# Epoch 60/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5365 - loss: 1.2865 - val_accuracy: 0.4500 - val_loss: 1.5287 - learning_rate: 8.4483e-04
# Epoch 61/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5360 - loss: 1.2986 - val_accuracy: 0.3900 - val_loss: 2.0609 - learning_rate: 8.3880e-04
# Epoch 62/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5235 - loss: 1.3314 - val_accuracy: 0.5000 - val_loss: 1.5483 - learning_rate: 8.3268e-04
# Epoch 63/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5375 - loss: 1.2939 - val_accuracy: 0.4450 - val_loss: 1.7447 - learning_rate: 8.2647e-04
# Epoch 64/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5657 - loss: 1.2258 - val_accuracy: 0.4800 - val_loss: 1.4535 - learning_rate: 8.2016e-04
# Epoch 65/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5506 - loss: 1.2480 - val_accuracy: 0.5200 - val_loss: 1.4388 - learning_rate: 8.1377e-04
# Epoch 66/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5604 - loss: 1.2396 - val_accuracy: 0.4800 - val_loss: 1.7039 - learning_rate: 8.0730e-04
# Epoch 67/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5706 - loss: 1.2097 - val_accuracy: 0.3900 - val_loss: 2.3879 - learning_rate: 8.0074e-04
# Epoch 68/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5546 - loss: 1.2392 - val_accuracy: 0.2850 - val_loss: 2.4887 - learning_rate: 7.9410e-04
# Epoch 69/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5562 - loss: 1.2731 - val_accuracy: 0.3650 - val_loss: 2.1787 - learning_rate: 7.8738e-04
# Epoch 70/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5418 - loss: 1.2386 - val_accuracy: 0.3850 - val_loss: 2.0793 - learning_rate: 7.8058e-04
# Epoch 71/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5715 - loss: 1.2433 - val_accuracy: 0.1900 - val_loss: 4.1655 - learning_rate: 7.7370e-04
# Epoch 72/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5583 - loss: 1.1794 - val_accuracy: 0.3600 - val_loss: 2.0834 - learning_rate: 7.6675e-04
# Epoch 73/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5575 - loss: 1.2151 - val_accuracy: 0.3700 - val_loss: 2.1093 - learning_rate: 7.5973e-04
# Epoch 74/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5610 - loss: 1.2010 - val_accuracy: 0.4400 - val_loss: 1.7308 - learning_rate: 7.5263e-04
# Epoch 75/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5376 - loss: 1.2243 - val_accuracy: 0.3550 - val_loss: 2.7113 - learning_rate: 7.4547e-04
# Epoch 76/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5503 - loss: 1.2422 - val_accuracy: 0.4150 - val_loss: 2.1005 - learning_rate: 7.3824e-04
# Epoch 77/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5667 - loss: 1.1879 - val_accuracy: 0.4050 - val_loss: 1.8901 - learning_rate: 7.3094e-04
# Epoch 78/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5833 - loss: 1.1134 - val_accuracy: 0.4850 - val_loss: 1.4950 - learning_rate: 7.2358e-04
# Epoch 79/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5897 - loss: 1.1673 - val_accuracy: 0.4800 - val_loss: 1.6132 - learning_rate: 7.1616e-04
# Epoch 80/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5839 - loss: 1.1784 - val_accuracy: 0.4500 - val_loss: 2.0225 - learning_rate: 7.0868e-04
# Epoch 81/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5967 - loss: 1.1199 - val_accuracy: 0.5200 - val_loss: 1.3818 - learning_rate: 7.0115e-04
# Epoch 82/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5819 - loss: 1.1551 - val_accuracy: 0.4450 - val_loss: 1.7433 - learning_rate: 6.9356e-04
# Epoch 83/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5675 - loss: 1.1973 - val_accuracy: 0.5150 - val_loss: 1.5337 - learning_rate: 6.8591e-04
# Epoch 84/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5616 - loss: 1.1616 - val_accuracy: 0.3750 - val_loss: 2.1516 - learning_rate: 6.7822e-04
# Epoch 85/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5263 - loss: 1.2153 - val_accuracy: 0.4450 - val_loss: 1.7551 - learning_rate: 6.7048e-04
# Epoch 86/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5508 - loss: 1.1771 - val_accuracy: 0.4600 - val_loss: 1.6765 - learning_rate: 6.6269e-04
# Epoch 87/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5520 - loss: 1.1894 - val_accuracy: 0.4150 - val_loss: 1.9677 - learning_rate: 6.5485e-04
# Epoch 88/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5535 - loss: 1.1543 - val_accuracy: 0.3000 - val_loss: 2.9825 - learning_rate: 6.4698e-04
# Epoch 89/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5743 - loss: 1.1804 - val_accuracy: 0.4550 - val_loss: 1.7171 - learning_rate: 6.3906e-04
# Epoch 90/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5756 - loss: 1.1531 - val_accuracy: 0.4300 - val_loss: 1.5011 - learning_rate: 6.3111e-04
# Epoch 91/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5907 - loss: 1.1271 - val_accuracy: 0.5250 - val_loss: 1.3985 - learning_rate: 6.2312e-04
# Epoch 92/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5753 - loss: 1.1443 - val_accuracy: 0.4650 - val_loss: 1.5894 - learning_rate: 6.1510e-04
# Epoch 93/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5778 - loss: 1.1076 - val_accuracy: 0.4650 - val_loss: 1.5999 - learning_rate: 6.0704e-04
# Epoch 94/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5847 - loss: 1.1250 - val_accuracy: 0.5500 - val_loss: 1.3019 - learning_rate: 5.9896e-04
# Epoch 95/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6116 - loss: 1.1358 - val_accuracy: 0.5400 - val_loss: 1.3057 - learning_rate: 5.9085e-04
# Epoch 96/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6002 - loss: 1.0877 - val_accuracy: 0.5150 - val_loss: 1.5853 - learning_rate: 5.8271e-04
# Epoch 97/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5806 - loss: 1.1331 - val_accuracy: 0.5050 - val_loss: 1.4261 - learning_rate: 5.7456e-04
# Epoch 98/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6103 - loss: 1.0901 - val_accuracy: 0.4600 - val_loss: 1.6139 - learning_rate: 5.6638e-04
# Epoch 99/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6185 - loss: 1.0869 - val_accuracy: 0.3800 - val_loss: 2.2603 - learning_rate: 5.5818e-04
# Epoch 100/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5773 - loss: 1.1487 - val_accuracy: 0.5550 - val_loss: 1.2905 - learning_rate: 5.4997e-04
# Epoch 101/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5767 - loss: 1.1022 - val_accuracy: 0.4850 - val_loss: 1.5100 - learning_rate: 5.4175e-04
# Epoch 102/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5709 - loss: 1.1215 - val_accuracy: 0.4750 - val_loss: 1.7323 - learning_rate: 5.3351e-04
# Epoch 103/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5604 - loss: 1.1698 - val_accuracy: 0.5350 - val_loss: 1.5795 - learning_rate: 5.2527e-04
# Epoch 104/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6003 - loss: 1.0873 - val_accuracy: 0.2950 - val_loss: 2.7678 - learning_rate: 5.1702e-04
# Epoch 105/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5601 - loss: 1.2381 - val_accuracy: 0.2800 - val_loss: 2.8678 - learning_rate: 5.0876e-04
# Epoch 106/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5337 - loss: 1.2404 - val_accuracy: 0.3300 - val_loss: 2.2112 - learning_rate: 5.0050e-04
# Epoch 107/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5668 - loss: 1.1246 - val_accuracy: 0.4100 - val_loss: 1.7894 - learning_rate: 4.9224e-04
# Epoch 108/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5986 - loss: 1.0927 - val_accuracy: 0.4550 - val_loss: 1.6614 - learning_rate: 4.8398e-04
# Epoch 109/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5599 - loss: 1.1226 - val_accuracy: 0.4750 - val_loss: 1.4650 - learning_rate: 4.7573e-04
# Epoch 110/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5815 - loss: 1.0927 - val_accuracy: 0.5150 - val_loss: 1.4336 - learning_rate: 4.6749e-04
# Epoch 111/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5760 - loss: 1.1646 - val_accuracy: 0.4400 - val_loss: 1.7718 - learning_rate: 4.5925e-04
# Epoch 112/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5752 - loss: 1.2222 - val_accuracy: 0.4150 - val_loss: 1.7915 - learning_rate: 4.5103e-04
# Epoch 113/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5497 - loss: 1.1611 - val_accuracy: 0.4250 - val_loss: 1.6020 - learning_rate: 4.4282e-04
# Epoch 114/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5744 - loss: 1.1419 - val_accuracy: 0.4400 - val_loss: 1.5371 - learning_rate: 4.3462e-04
# Epoch 115/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5737 - loss: 1.1382 - val_accuracy: 0.4550 - val_loss: 1.4964 - learning_rate: 4.2644e-04
# Epoch 116/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5707 - loss: 1.1042 - val_accuracy: 0.4200 - val_loss: 1.8513 - learning_rate: 4.1828e-04
# Epoch 117/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5911 - loss: 1.0931 - val_accuracy: 0.4400 - val_loss: 1.7025 - learning_rate: 4.1015e-04
# Epoch 118/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5891 - loss: 1.0656 - val_accuracy: 0.4550 - val_loss: 1.4497 - learning_rate: 4.0204e-04
# Epoch 119/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5832 - loss: 1.0844 - val_accuracy: 0.4650 - val_loss: 1.4114 - learning_rate: 3.9396e-04
# Epoch 120/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5911 - loss: 1.0731 - val_accuracy: 0.4450 - val_loss: 1.5256 - learning_rate: 3.8590e-04
# Epoch 121/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6118 - loss: 1.1027 - val_accuracy: 0.5450 - val_loss: 1.3256 - learning_rate: 3.7788e-04
# Epoch 122/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6071 - loss: 1.0560 - val_accuracy: 0.5550 - val_loss: 1.3809 - learning_rate: 3.6989e-04
# Epoch 123/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6007 - loss: 1.0516 - val_accuracy: 0.5650 - val_loss: 1.4000 - learning_rate: 3.6194e-04
# Epoch 124/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6275 - loss: 1.0461 - val_accuracy: 0.5400 - val_loss: 1.3193 - learning_rate: 3.5402e-04
# Epoch 125/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6074 - loss: 1.0649 - val_accuracy: 0.5350 - val_loss: 1.3864 - learning_rate: 3.4615e-04
# Epoch 126/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5936 - loss: 1.0525 - val_accuracy: 0.5050 - val_loss: 1.4813 - learning_rate: 3.3831e-04
# Epoch 127/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6118 - loss: 1.0543 - val_accuracy: 0.5450 - val_loss: 1.3130 - learning_rate: 3.3052e-04
# Epoch 128/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6294 - loss: 1.0493 - val_accuracy: 0.4950 - val_loss: 1.5684 - learning_rate: 3.2278e-04
# Epoch 129/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5832 - loss: 1.0620 - val_accuracy: 0.4550 - val_loss: 1.5581 - learning_rate: 3.1509e-04
# Epoch 130/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5954 - loss: 1.0871 - val_accuracy: 0.4900 - val_loss: 1.2994 - learning_rate: 3.0744e-04
# Epoch 131/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6002 - loss: 1.0552 - val_accuracy: 0.5750 - val_loss: 1.2637 - learning_rate: 2.9985e-04
# Epoch 132/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5919 - loss: 1.0453 - val_accuracy: 0.5350 - val_loss: 1.3495 - learning_rate: 2.9232e-04
# Epoch 133/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6174 - loss: 1.0433 - val_accuracy: 0.5600 - val_loss: 1.3217 - learning_rate: 2.8484e-04
# Epoch 134/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6398 - loss: 1.0112 - val_accuracy: 0.5700 - val_loss: 1.2758 - learning_rate: 2.7742e-04
# Epoch 135/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6165 - loss: 1.0467 - val_accuracy: 0.5550 - val_loss: 1.2757 - learning_rate: 2.7006e-04
# Epoch 136/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6362 - loss: 0.9910 - val_accuracy: 0.5850 - val_loss: 1.2513 - learning_rate: 2.6276e-04
# Epoch 137/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5859 - loss: 1.0568 - val_accuracy: 0.5850 - val_loss: 1.2637 - learning_rate: 2.5553e-04
# Epoch 138/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6301 - loss: 1.0179 - val_accuracy: 0.5850 - val_loss: 1.3088 - learning_rate: 2.4837e-04
# Epoch 139/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6163 - loss: 1.0344 - val_accuracy: 0.6000 - val_loss: 1.2559 - learning_rate: 2.4127e-04
# Epoch 140/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6221 - loss: 1.0008 - val_accuracy: 0.5450 - val_loss: 1.4317 - learning_rate: 2.3425e-04
# Epoch 141/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6264 - loss: 1.0034 - val_accuracy: 0.5650 - val_loss: 1.2630 - learning_rate: 2.2730e-04
# Epoch 142/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5801 - loss: 1.0495 - val_accuracy: 0.5650 - val_loss: 1.2877 - learning_rate: 2.2042e-04
# Epoch 143/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6116 - loss: 1.0801 - val_accuracy: 0.5600 - val_loss: 1.2545 - learning_rate: 2.1362e-04
# Epoch 144/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6432 - loss: 1.0069 - val_accuracy: 0.5900 - val_loss: 1.2569 - learning_rate: 2.0690e-04
# Epoch 145/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6125 - loss: 1.0414 - val_accuracy: 0.5400 - val_loss: 1.3661 - learning_rate: 2.0026e-04
# Epoch 146/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6443 - loss: 1.0019 - val_accuracy: 0.5950 - val_loss: 1.2480 - learning_rate: 1.9370e-04
# Epoch 147/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6192 - loss: 1.0119 - val_accuracy: 0.5500 - val_loss: 1.2852 - learning_rate: 1.8723e-04
# Epoch 148/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5901 - loss: 1.0639 - val_accuracy: 0.5850 - val_loss: 1.2614 - learning_rate: 1.8084e-04
# Epoch 149/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6170 - loss: 1.0284 - val_accuracy: 0.5700 - val_loss: 1.2526 - learning_rate: 1.7453e-04
# Epoch 150/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6559 - loss: 0.9750 - val_accuracy: 0.5900 - val_loss: 1.1868 - learning_rate: 1.6832e-04
# Epoch 151/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6158 - loss: 1.0019 - val_accuracy: 0.5900 - val_loss: 1.1950 - learning_rate: 1.6220e-04
# Epoch 152/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6025 - loss: 1.0098 - val_accuracy: 0.5700 - val_loss: 1.2539 - learning_rate: 1.5617e-04
# Epoch 153/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5971 - loss: 1.0657 - val_accuracy: 0.5700 - val_loss: 1.2159 - learning_rate: 1.5023e-04
# Epoch 154/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6370 - loss: 0.9653 - val_accuracy: 0.5850 - val_loss: 1.2072 - learning_rate: 1.4439e-04
# Epoch 155/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6175 - loss: 1.0491 - val_accuracy: 0.5700 - val_loss: 1.2214 - learning_rate: 1.3865e-04
# Epoch 156/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6462 - loss: 0.9835 - val_accuracy: 0.5800 - val_loss: 1.2466 - learning_rate: 1.3301e-04
# Epoch 157/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6147 - loss: 1.0295 - val_accuracy: 0.5900 - val_loss: 1.2737 - learning_rate: 1.2746e-04
# Epoch 158/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6262 - loss: 1.0263 - val_accuracy: 0.5950 - val_loss: 1.2348 - learning_rate: 1.2202e-04
# Epoch 159/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6232 - loss: 1.0025 - val_accuracy: 0.6050 - val_loss: 1.2075 - learning_rate: 1.1668e-04
# Epoch 160/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5951 - loss: 1.0546 - val_accuracy: 0.5750 - val_loss: 1.2670 - learning_rate: 1.1145e-04
# Epoch 161/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6358 - loss: 1.0277 - val_accuracy: 0.5850 - val_loss: 1.2019 - learning_rate: 1.0632e-04
# Epoch 162/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6403 - loss: 0.9703 - val_accuracy: 0.6000 - val_loss: 1.1982 - learning_rate: 1.0131e-04
# Epoch 163/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6402 - loss: 0.9705 - val_accuracy: 0.6150 - val_loss: 1.1949 - learning_rate: 9.6396e-05
# Epoch 164/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6237 - loss: 0.9712 - val_accuracy: 0.5950 - val_loss: 1.2216 - learning_rate: 9.1597e-05
# Epoch 165/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6231 - loss: 1.0025 - val_accuracy: 0.6100 - val_loss: 1.1819 - learning_rate: 8.6910e-05
# Epoch 166/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6610 - loss: 0.9535 - val_accuracy: 0.6050 - val_loss: 1.1788 - learning_rate: 8.2335e-05
# Epoch 167/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6065 - loss: 1.0033 - val_accuracy: 0.6100 - val_loss: 1.2226 - learning_rate: 7.7875e-05
# Epoch 168/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6249 - loss: 1.0061 - val_accuracy: 0.6150 - val_loss: 1.2032 - learning_rate: 7.3531e-05
# Epoch 169/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6185 - loss: 0.9799 - val_accuracy: 0.5900 - val_loss: 1.2069 - learning_rate: 6.9303e-05
# Epoch 170/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6086 - loss: 1.0013 - val_accuracy: 0.6150 - val_loss: 1.2228 - learning_rate: 6.5194e-05
# Epoch 171/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6273 - loss: 0.9845 - val_accuracy: 0.6150 - val_loss: 1.2271 - learning_rate: 6.1203e-05
# Epoch 172/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6454 - loss: 1.0130 - val_accuracy: 0.6050 - val_loss: 1.1995 - learning_rate: 5.7332e-05
# Epoch 173/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6313 - loss: 1.0037 - val_accuracy: 0.5950 - val_loss: 1.1898 - learning_rate: 5.3583e-05
# Epoch 174/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6520 - loss: 1.0082 - val_accuracy: 0.5700 - val_loss: 1.2240 - learning_rate: 4.9955e-05
# Epoch 175/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6283 - loss: 1.0258 - val_accuracy: 0.6050 - val_loss: 1.1868 - learning_rate: 4.6451e-05
# Epoch 176/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6359 - loss: 0.9889 - val_accuracy: 0.6150 - val_loss: 1.1897 - learning_rate: 4.3071e-05
# Epoch 177/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6388 - loss: 0.9853 - val_accuracy: 0.6100 - val_loss: 1.1820 - learning_rate: 3.9816e-05
# Epoch 178/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6301 - loss: 1.0451 - val_accuracy: 0.6100 - val_loss: 1.1789 - learning_rate: 3.6687e-05
# Epoch 179/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6431 - loss: 1.0132 - val_accuracy: 0.6150 - val_loss: 1.1766 - learning_rate: 3.3685e-05
# Epoch 180/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6146 - loss: 1.0364 - val_accuracy: 0.6050 - val_loss: 1.1780 - learning_rate: 3.0810e-05
# Epoch 181/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6564 - loss: 0.9729 - val_accuracy: 0.6150 - val_loss: 1.1934 - learning_rate: 2.8064e-05
# Epoch 182/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6381 - loss: 0.9591 - val_accuracy: 0.6100 - val_loss: 1.1868 - learning_rate: 2.5447e-05
# Epoch 183/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6202 - loss: 1.0239 - val_accuracy: 0.6050 - val_loss: 1.1875 - learning_rate: 2.2960e-05
# Epoch 184/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6359 - loss: 0.9995 - val_accuracy: 0.6100 - val_loss: 1.1858 - learning_rate: 2.0604e-05
# Epoch 185/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6441 - loss: 0.9609 - val_accuracy: 0.6100 - val_loss: 1.1855 - learning_rate: 1.8378e-05
# Epoch 186/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6119 - loss: 0.9996 - val_accuracy: 0.6100 - val_loss: 1.1852 - learning_rate: 1.6285e-05
# Epoch 187/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6479 - loss: 0.9813 - val_accuracy: 0.6100 - val_loss: 1.1833 - learning_rate: 1.4323e-05
# Epoch 188/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6017 - loss: 0.9985 - val_accuracy: 0.6150 - val_loss: 1.1848 - learning_rate: 1.2495e-05
# Epoch 189/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6114 - loss: 1.0368 - val_accuracy: 0.6150 - val_loss: 1.1864 - learning_rate: 1.0800e-05
# Epoch 190/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6322 - loss: 1.0031 - val_accuracy: 0.6200 - val_loss: 1.1859 - learning_rate: 9.2392e-06
# Epoch 191/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6428 - loss: 0.9752 - val_accuracy: 0.6150 - val_loss: 1.1852 - learning_rate: 7.8125e-06
# Epoch 192/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6449 - loss: 0.9696 - val_accuracy: 0.6150 - val_loss: 1.1867 - learning_rate: 6.5205e-06
# Epoch 193/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6395 - loss: 0.9976 - val_accuracy: 0.6150 - val_loss: 1.1861 - learning_rate: 5.3636e-06
# Epoch 194/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6121 - loss: 0.9995 - val_accuracy: 0.6200 - val_loss: 1.1843 - learning_rate: 4.3420e-06
# Epoch 195/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6442 - loss: 0.9630 - val_accuracy: 0.6200 - val_loss: 1.1835 - learning_rate: 3.4561e-06
# Epoch 196/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6188 - loss: 1.0309 - val_accuracy: 0.6200 - val_loss: 1.1830 - learning_rate: 2.7060e-06
# Epoch 197/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6273 - loss: 1.0224 - val_accuracy: 0.6200 - val_loss: 1.1828 - learning_rate: 2.0921e-06
# Epoch 198/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6154 - loss: 1.0112 - val_accuracy: 0.6200 - val_loss: 1.1825 - learning_rate: 1.6144e-06
# Epoch 199/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6269 - loss: 1.0256 - val_accuracy: 0.6200 - val_loss: 1.1818 - learning_rate: 1.2731e-06
# Epoch 200/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6222 - loss: 1.0193 - val_accuracy: 0.6200 - val_loss: 1.1817 - learning_rate: 1.0683e-06
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 671ms/step - accuracy: 0.5717 - loss: 1.3787
# Test Loss: 1.3529000282287598
# Test Accuracy: 0.5699999928474426
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 721ms/step
# Predicted Labels: [1 9 6 5 0 9 9 2 6 5 5 0 8 0 9 4 8 5 2 1 2 6 2 5 9 1 7 1 2 0 6 5 5 4 1 6 9
#  4 2 0 8 2 7 2 5 5 6 1 4 9 6 6 4 5 7 8 8 1 1 9 6 1 8 1 6 9 5 1 9 0 9 3 1 7
#  8 4 7 7 7 2 3 7 7 4 5 5 4 4 2 5 9 7 7 3 3 5 5 5 2 8 8 6 8 2 9 5 3 4 9 3 2
#  8 1 2 1 2 1 6 8 2 1 3 5 9 5 5 6 3 9 3 9 3 7 5 7 2 0 9 4 8 5 4 3 6 2 8 4 0
#  1 4 7 1 1 0 9 2 7 5 1 0 7 3 7 5 6 6 9 9 4 0 6 5 0 2 2 0 7 3 0 3 0 4 1 4 1
#  8 6 2 2 2 4 1 7 3 4 2 2 1 2 2]
# True Labels: [1 0 6 5 0 2 9 2 4 5 0 0 8 0 9 3 8 5 3 9 2 6 0 2 0 1 7 8 5 5 6 2 5 4 1 6 9
#  4 2 3 8 9 7 0 5 5 6 1 4 7 4 6 4 5 8 3 3 1 1 8 6 8 8 9 3 9 9 1 9 7 6 8 1 7
#  8 4 3 7 7 7 3 7 8 4 5 9 8 4 9 5 6 8 6 3 2 5 5 2 8 8 6 0 8 7 6 9 3 3 6 3 0
#  0 1 2 1 2 1 9 8 7 3 0 5 9 8 1 6 4 6 3 6 4 7 5 7 2 3 2 3 8 5 0 3 0 2 4 4 0
#  1 4 7 1 1 0 9 0 6 5 1 0 3 3 4 5 8 9 9 2 7 0 6 5 0 9 7 1 7 4 2 3 6 4 9 4 1
#  7 6 2 5 2 4 1 7 7 4 2 2 1 9 2]

# %%
plot_model_training(music_genre_rnn_model.history)
plot_prediction_heatmap(music_genre_rnn_model, padded_test_features, test_labels, label_encoder)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 693ms/step

# %% [markdown]
# # Deep-Learning: Hybrid CNNs & RNNs with Transfer Learning

# %%
class MusicGenreHybridModel:
    def __init__(self, input_shapes, num_classes, lr_max=1e-3, lr_min=1e-6, warmup_epochs=10, epochs=250, batch_size=64):
        self.input_shapes = input_shapes
        self.num_classes = num_classes
        self.lr_max = lr_max
        self.lr_min = lr_min
        self.warmup_epochs = warmup_epochs
        self.epochs = epochs
        self.batch_size = batch_size
        self.model = None
        self.optimizer = None
        self.lr_callback = None
        self.history = None
        self.policy = tf.keras.mixed_precision.set_global_policy('float32')
        self._initialize_model()

    def _initialize_model(self):
        """Initialize and compile the hybrid model."""
        self.optimizer = Adam(learning_rate=self.lr_max)

        T_max = self.epochs - self.warmup_epochs
        self.lr_callback = LearningRateScheduler(lambda epoch: self.combined_lr_schedule(epoch, self.lr_max, self.lr_min, self.warmup_epochs, T_max))

        # Create the hybrid model
        self.model = self._create_hybrid_model(self.input_shapes, self.num_classes)

        self.model.compile(optimizer=self.optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
        self.model.summary()

    def _create_hybrid_model(self, input_shapes, num_classes):
        """Create the hybrid model for music genre classification."""
        inputs = []
        processed_features = []

        for key, shape in input_shapes.items():
            input_layer = layers.Input(shape=(None, 1), name=f"{key}_input")
            inputs.append(input_layer)

            if key == 'mel_spectrogram' or key == 'chroma':
                time_dimension = layers.Lambda(lambda x: tf.shape(x)[1] // 128)(input_layer)
                padded_input = layers.Lambda(lambda x: tf.pad(x, [[0, 0], [0, 128 - tf.shape(x)[1] % 128], [0, 0]]))(input_layer)
                reshaped_input = layers.Reshape((-1, 128, 1))(padded_input)
                x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(reshaped_input)
                x = layers.BatchNormalization()(x)
                x = layers.SpatialDropout2D(0.2)(x)
                residual = x
                residual = layers.Conv2D(32, (1, 1), padding='same')(residual)
                x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
                x = layers.BatchNormalization()(x)
                x = layers.SpatialDropout2D(0.2)(x)
                x = layers.Add()([x, residual])
                x = layers.MaxPooling2D((2, 2))(x)
                x = layers.GlobalAveragePooling2D()(x)
            elif key == 'wavelet' or key == 'mfcc':
                x = layers.Bidirectional(layers.LSTM(32, return_sequences=True))(input_layer)
                x = layers.BatchNormalization()(x)
                x = layers.SpatialDropout1D(0.3)(x)
                x = layers.GlobalAveragePooling1D()(x)
            elif key == 'vggish':
                x = layers.Bidirectional(layers.LSTM(32, return_sequences=True))(input_layer)
                x = layers.BatchNormalization()(x)
                x = layers.SpatialDropout1D(0.3)(x)
                x = layers.Bidirectional(layers.LSTM(16))(x)
                x = layers.BatchNormalization()(x)
                x = layers.GlobalAveragePooling1D()(x)
            processed_features.append(x)

        combined = layers.concatenate(processed_features)
        x = layers.Dense(128, activation='relu')(combined)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(0.4)(x)
        output_layer = layers.Dense(num_classes, activation='softmax')(x)

        return models.Model(inputs=inputs, outputs=output_layer)

    def combined_lr_schedule(self, epoch, lr_max, lr_min, warmup_epochs, T_max):
        """Combined warm-up and cosine annealing learning rate schedule."""
        if epoch < warmup_epochs:
            return lr_min + (lr_max - lr_min) * (epoch / warmup_epochs)
        else:
            return lr_min + (lr_max - lr_min) * (1 + math.cos((epoch - warmup_epochs) * math.pi / T_max)) / 2

    def train(self, train_features, train_labels, val_features, val_labels):
        """Train the model."""
        self.history = self.model.fit(
            train_features,
            train_labels.astype('int32'),
            validation_data=(val_features, val_labels.astype('int32')),
            epochs=self.epochs,
            batch_size=self.batch_size,
            callbacks=[self.lr_callback]
        )

    def evaluate(self, test_features, test_labels):
        """Evaluate the model on the test set."""
        test_loss, test_accuracy = self.model.evaluate(
            test_features,
            test_labels.astype('int32')
        )
        print(f"Test Loss: {test_loss}")
        print(f"Test Accuracy: {test_accuracy}")

    def predict(self, test_features, test_labels):
        """Make predictions on the test set."""
        predictions = self.model.predict(test_features)
        predicted_labels = np.argmax(predictions, axis=1)
        print(f"Predicted Labels: {predicted_labels}")
        print(f"True Labels: {test_labels.astype('int32')}")

input_shapes_hybrid = {
    'mel_spectrogram': (None, 1),
    'wavelet': (None, 1),
    'mfcc': (None, 1),
    'chroma': (None, 1),
}

music_genre_hybrid_model = MusicGenreHybridModel(input_shapes_hybrid, num_classes)
music_genre_hybrid_model.train(padded_train_features, train_labels, padded_val_features, val_labels)
music_genre_hybrid_model.evaluate(padded_test_features, test_labels)
music_genre_hybrid_model.predict(padded_test_features, test_labels)
# Out:
# Model: "functional_24"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ mel_spectrogram_input     │ (None, None, 1)        │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ chroma_input (InputLayer) │ (None, None, 1)        │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_61 (Lambda)        │ (None, None, 1)        │              0 │ mel_spectrogram_input… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_63 (Lambda)        │ (None, None, 1)        │              0 │ chroma_input[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_30 (Reshape)      │ (None, None, 128, 1)   │              0 │ lambda_61[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_31 (Reshape)      │ (None, None, 128, 1)   │              0 │ lambda_63[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_90 (Conv2D)        │ (None, None, 128, 16)  │            160 │ reshape_30[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_93 (Conv2D)        │ (None, None, 128, 16)  │            160 │ reshape_31[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_102   │ (None, None, 128, 16)  │             64 │ conv2d_90[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_106   │ (None, None, 128, 16)  │             64 │ conv2d_93[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_60      │ (None, None, 128, 16)  │              0 │ batch_normalization_1… │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_62      │ (None, None, 128, 16)  │              0 │ batch_normalization_1… │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_92 (Conv2D)        │ (None, None, 128, 32)  │          4,640 │ spatial_dropout2d_60[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_95 (Conv2D)        │ (None, None, 128, 32)  │          4,640 │ spatial_dropout2d_62[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_103   │ (None, None, 128, 32)  │            128 │ conv2d_92[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ wavelet_input             │ (None, None, 1)        │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ mfcc_input (InputLayer)   │ (None, None, 1)        │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_107   │ (None, None, 128, 32)  │            128 │ conv2d_95[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_61      │ (None, None, 128, 32)  │              0 │ batch_normalization_1… │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_91 (Conv2D)        │ (None, None, 128, 32)  │            544 │ spatial_dropout2d_60[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bidirectional_18          │ (None, None, 64)       │          8,704 │ wavelet_input[0][0]    │
# │ (Bidirectional)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bidirectional_19          │ (None, None, 64)       │          8,704 │ mfcc_input[0][0]       │
# │ (Bidirectional)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_63      │ (None, None, 128, 32)  │              0 │ batch_normalization_1… │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_94 (Conv2D)        │ (None, None, 128, 32)  │            544 │ spatial_dropout2d_62[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_30 (Add)              │ (None, None, 128, 32)  │              0 │ spatial_dropout2d_61[… │
# │                           │                        │                │ conv2d_91[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_104   │ (None, None, 64)       │            256 │ bidirectional_18[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_105   │ (None, None, 64)       │            256 │ bidirectional_19[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_31 (Add)              │ (None, None, 128, 32)  │              0 │ spatial_dropout2d_63[… │
# │                           │                        │                │ conv2d_94[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_30          │ (None, None, 64, 32)   │              0 │ add_30[0][0]           │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout1d_18      │ (None, None, 64)       │              0 │ batch_normalization_1… │
# │ (SpatialDropout1D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout1d_19      │ (None, None, 64)       │              0 │ batch_normalization_1… │
# │ (SpatialDropout1D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_31          │ (None, None, 64, 32)   │              0 │ add_31[0][0]           │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 32)             │              0 │ max_pooling2d_30[0][0] │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling1d… │ (None, 64)             │              0 │ spatial_dropout1d_18[… │
# │ (GlobalAveragePooling1D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling1d… │ (None, 64)             │              0 │ spatial_dropout1d_19[… │
# │ (GlobalAveragePooling1D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 32)             │              0 │ max_pooling2d_31[0][0] │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_24            │ (None, 192)            │              0 │ global_average_poolin… │
# │ (Concatenate)             │                        │                │ global_average_poolin… │
# │                           │                        │                │ global_average_poolin… │
# │                           │                        │                │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_48 (Dense)          │ (None, 128)            │         24,704 │ concatenate_24[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_108   │ (None, 128)            │            512 │ dense_48[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_24 (Dropout)      │ (None, 128)            │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_49 (Dense)          │ (None, 10)             │          1,290 │ dropout_24[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 55,498 (216.79 KB)
#  Trainable params: 54,794 (214.04 KB)
#  Non-trainable params: 704 (2.75 KB)
# Epoch 1/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 0.1121 - loss: 3.0990 - val_accuracy: 0.1000 - val_loss: 2.3053 - learning_rate: 1.0000e-06
# Epoch 2/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.1034 - loss: 3.1269 - val_accuracy: 0.1100 - val_loss: 2.3011 - learning_rate: 1.0090e-04
# Epoch 3/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.1215 - loss: 2.9309 - val_accuracy: 0.2150 - val_loss: 2.2962 - learning_rate: 2.0080e-04
# Epoch 4/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.1786 - loss: 2.6103 - val_accuracy: 0.2050 - val_loss: 2.2902 - learning_rate: 3.0070e-04
# Epoch 5/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.1822 - loss: 2.5454 - val_accuracy: 0.1700 - val_loss: 2.2824 - learning_rate: 4.0060e-04
# Epoch 6/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.2539 - loss: 2.2942 - val_accuracy: 0.1250 - val_loss: 2.2756 - learning_rate: 5.0050e-04
# Epoch 7/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.2314 - loss: 2.3624 - val_accuracy: 0.1000 - val_loss: 2.2737 - learning_rate: 6.0040e-04
# Epoch 8/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.3089 - loss: 2.1165 - val_accuracy: 0.1000 - val_loss: 2.2740 - learning_rate: 7.0030e-04
# Epoch 9/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.3094 - loss: 2.0231 - val_accuracy: 0.1000 - val_loss: 2.2737 - learning_rate: 8.0020e-04
# Epoch 10/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.3403 - loss: 1.9138 - val_accuracy: 0.1000 - val_loss: 2.2714 - learning_rate: 9.0010e-04
# Epoch 11/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.3597 - loss: 1.8386 - val_accuracy: 0.1000 - val_loss: 2.2770 - learning_rate: 0.0010
# Epoch 12/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.3522 - loss: 1.8265 - val_accuracy: 0.1000 - val_loss: 2.2802 - learning_rate: 9.9996e-04
# Epoch 13/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.3845 - loss: 1.7751 - val_accuracy: 0.1000 - val_loss: 2.2945 - learning_rate: 9.9983e-04
# Epoch 14/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4095 - loss: 1.6921 - val_accuracy: 0.1000 - val_loss: 2.3069 - learning_rate: 9.9961e-04
# Epoch 15/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.3703 - loss: 1.6792 - val_accuracy: 0.1000 - val_loss: 2.3348 - learning_rate: 9.9932e-04
# Epoch 16/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4120 - loss: 1.6748 - val_accuracy: 0.1000 - val_loss: 2.3640 - learning_rate: 9.9893e-04
# Epoch 17/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4443 - loss: 1.6438 - val_accuracy: 0.1050 - val_loss: 2.3772 - learning_rate: 9.9846e-04
# Epoch 18/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4530 - loss: 1.5803 - val_accuracy: 0.1050 - val_loss: 2.3923 - learning_rate: 9.9790e-04
# Epoch 19/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4291 - loss: 1.6116 - val_accuracy: 0.1100 - val_loss: 2.4356 - learning_rate: 9.9726e-04
# Epoch 20/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4233 - loss: 1.6016 - val_accuracy: 0.1050 - val_loss: 2.5284 - learning_rate: 9.9654e-04
# Epoch 21/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4660 - loss: 1.5248 - val_accuracy: 0.1100 - val_loss: 2.5503 - learning_rate: 9.9573e-04
# Epoch 22/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4779 - loss: 1.5345 - val_accuracy: 0.1100 - val_loss: 2.5827 - learning_rate: 9.9483e-04
# Epoch 23/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4448 - loss: 1.5381 - val_accuracy: 0.1150 - val_loss: 2.5963 - learning_rate: 9.9385e-04
# Epoch 24/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4847 - loss: 1.4135 - val_accuracy: 0.1250 - val_loss: 2.6671 - learning_rate: 9.9279e-04
# Epoch 25/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4775 - loss: 1.4453 - val_accuracy: 0.1250 - val_loss: 2.7100 - learning_rate: 9.9164e-04
# Epoch 26/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5085 - loss: 1.3907 - val_accuracy: 0.1250 - val_loss: 2.7976 - learning_rate: 9.9040e-04
# Epoch 27/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4404 - loss: 1.4277 - val_accuracy: 0.1300 - val_loss: 2.8768 - learning_rate: 9.8908e-04
# Epoch 28/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4841 - loss: 1.4005 - val_accuracy: 0.1400 - val_loss: 2.8033 - learning_rate: 9.8768e-04
# Epoch 29/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4924 - loss: 1.3543 - val_accuracy: 0.1450 - val_loss: 2.8793 - learning_rate: 9.8620e-04
# Epoch 30/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5386 - loss: 1.3395 - val_accuracy: 0.1350 - val_loss: 2.9982 - learning_rate: 9.8463e-04
# Epoch 31/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5345 - loss: 1.2756 - val_accuracy: 0.1700 - val_loss: 2.7230 - learning_rate: 9.8298e-04
# Epoch 32/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.4923 - loss: 1.3574 - val_accuracy: 0.1500 - val_loss: 2.8183 - learning_rate: 9.8125e-04
# Epoch 33/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5198 - loss: 1.3369 - val_accuracy: 0.1650 - val_loss: 2.8804 - learning_rate: 9.7943e-04
# Epoch 34/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5178 - loss: 1.3242 - val_accuracy: 0.1700 - val_loss: 2.7856 - learning_rate: 9.7753e-04
# Epoch 35/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5547 - loss: 1.2408 - val_accuracy: 0.1850 - val_loss: 2.8172 - learning_rate: 9.7555e-04
# Epoch 36/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5319 - loss: 1.2912 - val_accuracy: 0.2000 - val_loss: 2.8655 - learning_rate: 9.7349e-04
# Epoch 37/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5474 - loss: 1.2308 - val_accuracy: 0.2100 - val_loss: 2.4663 - learning_rate: 9.7135e-04
# Epoch 38/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5860 - loss: 1.1994 - val_accuracy: 0.2250 - val_loss: 2.5353 - learning_rate: 9.6913e-04
# Epoch 39/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5656 - loss: 1.2465 - val_accuracy: 0.2150 - val_loss: 2.9466 - learning_rate: 9.6682e-04
# Epoch 40/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5790 - loss: 1.1826 - val_accuracy: 0.2100 - val_loss: 3.4595 - learning_rate: 9.6444e-04
# Epoch 41/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5782 - loss: 1.1994 - val_accuracy: 0.2150 - val_loss: 3.1005 - learning_rate: 9.6198e-04
# Epoch 42/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5880 - loss: 1.1902 - val_accuracy: 0.2500 - val_loss: 2.9504 - learning_rate: 9.5944e-04
# Epoch 43/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5568 - loss: 1.2074 - val_accuracy: 0.2050 - val_loss: 3.4470 - learning_rate: 9.5682e-04
# Epoch 44/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5624 - loss: 1.1865 - val_accuracy: 0.2250 - val_loss: 3.9369 - learning_rate: 9.5412e-04
# Epoch 45/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5678 - loss: 1.2353 - val_accuracy: 0.2500 - val_loss: 2.9261 - learning_rate: 9.5134e-04
# Epoch 46/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5744 - loss: 1.1645 - val_accuracy: 0.2550 - val_loss: 2.8580 - learning_rate: 9.4849e-04
# Epoch 47/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5831 - loss: 1.1483 - val_accuracy: 0.2700 - val_loss: 2.6520 - learning_rate: 9.4556e-04
# Epoch 48/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6320 - loss: 1.1407 - val_accuracy: 0.2550 - val_loss: 2.8428 - learning_rate: 9.4255e-04
# Epoch 49/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6059 - loss: 1.1084 - val_accuracy: 0.2450 - val_loss: 2.7198 - learning_rate: 9.3947e-04
# Epoch 50/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5909 - loss: 1.1169 - val_accuracy: 0.3200 - val_loss: 2.1602 - learning_rate: 9.3631e-04
# Epoch 51/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6035 - loss: 1.1186 - val_accuracy: 0.3550 - val_loss: 2.0135 - learning_rate: 9.3308e-04
# Epoch 52/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5940 - loss: 1.0677 - val_accuracy: 0.4050 - val_loss: 2.0219 - learning_rate: 9.2977e-04
# Epoch 53/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5663 - loss: 1.1292 - val_accuracy: 0.4200 - val_loss: 1.8286 - learning_rate: 9.2639e-04
# Epoch 54/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6354 - loss: 1.0186 - val_accuracy: 0.4300 - val_loss: 1.8098 - learning_rate: 9.2294e-04
# Epoch 55/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5781 - loss: 1.0776 - val_accuracy: 0.2950 - val_loss: 2.3816 - learning_rate: 9.1942e-04
# Epoch 56/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6116 - loss: 1.0722 - val_accuracy: 0.3000 - val_loss: 2.3307 - learning_rate: 9.1582e-04
# Epoch 57/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6255 - loss: 1.0436 - val_accuracy: 0.3100 - val_loss: 2.2420 - learning_rate: 9.1215e-04
# Epoch 58/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5989 - loss: 1.0440 - val_accuracy: 0.2950 - val_loss: 2.3187 - learning_rate: 9.0841e-04
# Epoch 59/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6377 - loss: 0.9889 - val_accuracy: 0.3300 - val_loss: 2.4467 - learning_rate: 9.0460e-04
# Epoch 60/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5889 - loss: 1.0896 - val_accuracy: 0.4050 - val_loss: 1.9151 - learning_rate: 9.0073e-04
# Epoch 61/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5972 - loss: 1.0550 - val_accuracy: 0.3150 - val_loss: 2.7148 - learning_rate: 8.9678e-04
# Epoch 62/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6387 - loss: 1.0425 - val_accuracy: 0.4450 - val_loss: 1.6469 - learning_rate: 8.9277e-04
# Epoch 63/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6466 - loss: 0.9893 - val_accuracy: 0.3850 - val_loss: 1.9305 - learning_rate: 8.8868e-04
# Epoch 64/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6431 - loss: 0.9785 - val_accuracy: 0.3850 - val_loss: 1.9991 - learning_rate: 8.8454e-04
# Epoch 65/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6447 - loss: 1.0098 - val_accuracy: 0.4150 - val_loss: 1.8946 - learning_rate: 8.8032e-04
# Epoch 66/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6501 - loss: 1.0398 - val_accuracy: 0.4850 - val_loss: 1.5093 - learning_rate: 8.7604e-04
# Epoch 67/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6430 - loss: 1.0126 - val_accuracy: 0.4250 - val_loss: 1.8148 - learning_rate: 8.7170e-04
# Epoch 68/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6677 - loss: 0.9322 - val_accuracy: 0.4650 - val_loss: 1.5510 - learning_rate: 8.6729e-04
# Epoch 69/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6538 - loss: 0.9802 - val_accuracy: 0.5300 - val_loss: 1.4285 - learning_rate: 8.6282e-04
# Epoch 70/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6637 - loss: 0.9663 - val_accuracy: 0.4900 - val_loss: 1.5300 - learning_rate: 8.5829e-04
# Epoch 71/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6437 - loss: 0.9988 - val_accuracy: 0.5200 - val_loss: 1.4100 - learning_rate: 8.5370e-04
# Epoch 72/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6583 - loss: 0.9524 - val_accuracy: 0.5050 - val_loss: 1.4248 - learning_rate: 8.4905e-04
# Epoch 73/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6550 - loss: 0.9513 - val_accuracy: 0.4800 - val_loss: 1.5557 - learning_rate: 8.4433e-04
# Epoch 74/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6733 - loss: 0.9220 - val_accuracy: 0.5750 - val_loss: 1.3090 - learning_rate: 8.3956e-04
# Epoch 75/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6359 - loss: 0.9554 - val_accuracy: 0.5450 - val_loss: 1.2996 - learning_rate: 8.3473e-04
# Epoch 76/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6761 - loss: 0.8998 - val_accuracy: 0.4750 - val_loss: 1.6975 - learning_rate: 8.2984e-04
# Epoch 77/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6909 - loss: 0.8816 - val_accuracy: 0.5900 - val_loss: 1.3409 - learning_rate: 8.2490e-04
# Epoch 78/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6778 - loss: 0.9082 - val_accuracy: 0.6450 - val_loss: 1.1325 - learning_rate: 8.1990e-04
# Epoch 79/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6915 - loss: 0.9068 - val_accuracy: 0.4700 - val_loss: 1.5853 - learning_rate: 8.1485e-04
# Epoch 80/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6530 - loss: 0.9295 - val_accuracy: 0.3850 - val_loss: 2.6113 - learning_rate: 8.0974e-04
# Epoch 81/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6591 - loss: 0.9663 - val_accuracy: 0.3850 - val_loss: 1.7963 - learning_rate: 8.0458e-04
# Epoch 82/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6753 - loss: 0.8925 - val_accuracy: 0.5700 - val_loss: 1.5715 - learning_rate: 7.9936e-04
# Epoch 83/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6687 - loss: 0.8828 - val_accuracy: 0.3700 - val_loss: 2.6264 - learning_rate: 7.9410e-04
# Epoch 84/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6825 - loss: 0.9664 - val_accuracy: 0.6100 - val_loss: 1.1244 - learning_rate: 7.8878e-04
# Epoch 85/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6979 - loss: 0.8605 - val_accuracy: 0.5950 - val_loss: 1.2920 - learning_rate: 7.8342e-04
# Epoch 86/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6989 - loss: 0.8701 - val_accuracy: 0.6400 - val_loss: 1.1425 - learning_rate: 7.7801e-04
# Epoch 87/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6523 - loss: 0.9038 - val_accuracy: 0.6150 - val_loss: 1.1267 - learning_rate: 7.7255e-04
# Epoch 88/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6441 - loss: 0.9123 - val_accuracy: 0.6300 - val_loss: 1.1013 - learning_rate: 7.6704e-04
# Epoch 89/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6839 - loss: 0.8552 - val_accuracy: 0.6150 - val_loss: 1.1675 - learning_rate: 7.6149e-04
# Epoch 90/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7011 - loss: 0.8487 - val_accuracy: 0.4450 - val_loss: 1.7006 - learning_rate: 7.5589e-04
# Epoch 91/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6867 - loss: 0.8349 - val_accuracy: 0.5750 - val_loss: 1.2068 - learning_rate: 7.5025e-04
# Epoch 92/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6905 - loss: 0.8383 - val_accuracy: 0.5400 - val_loss: 1.2926 - learning_rate: 7.4457e-04
# Epoch 93/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6946 - loss: 0.8617 - val_accuracy: 0.5700 - val_loss: 1.1248 - learning_rate: 7.3884e-04
# Epoch 94/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6974 - loss: 0.8604 - val_accuracy: 0.4850 - val_loss: 1.5853 - learning_rate: 7.3307e-04
# Epoch 95/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6876 - loss: 0.8590 - val_accuracy: 0.4850 - val_loss: 1.4860 - learning_rate: 7.2727e-04
# Epoch 96/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6963 - loss: 0.8806 - val_accuracy: 0.6150 - val_loss: 1.1483 - learning_rate: 7.2142e-04
# Epoch 97/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7166 - loss: 0.8031 - val_accuracy: 0.6250 - val_loss: 1.0456 - learning_rate: 7.1554e-04
# Epoch 98/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7342 - loss: 0.7764 - val_accuracy: 0.5400 - val_loss: 1.4963 - learning_rate: 7.0962e-04
# Epoch 99/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7320 - loss: 0.7863 - val_accuracy: 0.6250 - val_loss: 1.1596 - learning_rate: 7.0366e-04
# Epoch 100/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7372 - loss: 0.8057 - val_accuracy: 0.6600 - val_loss: 0.9477 - learning_rate: 6.9767e-04
# Epoch 101/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7246 - loss: 0.7530 - val_accuracy: 0.6650 - val_loss: 1.0220 - learning_rate: 6.9165e-04
# Epoch 102/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7081 - loss: 0.8182 - val_accuracy: 0.5600 - val_loss: 1.2600 - learning_rate: 6.8559e-04
# Epoch 103/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7154 - loss: 0.7990 - val_accuracy: 0.6400 - val_loss: 1.0911 - learning_rate: 6.7950e-04
# Epoch 104/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7224 - loss: 0.8130 - val_accuracy: 0.6100 - val_loss: 1.1675 - learning_rate: 6.7339e-04
# Epoch 105/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6866 - loss: 0.8279 - val_accuracy: 0.6150 - val_loss: 1.2610 - learning_rate: 6.6724e-04
# Epoch 106/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7471 - loss: 0.7621 - val_accuracy: 0.6050 - val_loss: 1.2232 - learning_rate: 6.6106e-04
# Epoch 107/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7308 - loss: 0.7382 - val_accuracy: 0.5000 - val_loss: 1.4971 - learning_rate: 6.5485e-04
# Epoch 108/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7326 - loss: 0.7544 - val_accuracy: 0.5550 - val_loss: 1.2579 - learning_rate: 6.4862e-04
# Epoch 109/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7220 - loss: 0.8196 - val_accuracy: 0.5850 - val_loss: 1.1748 - learning_rate: 6.4237e-04
# Epoch 110/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7403 - loss: 0.7782 - val_accuracy: 0.6000 - val_loss: 1.2591 - learning_rate: 6.3608e-04
# Epoch 111/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7415 - loss: 0.7488 - val_accuracy: 0.6450 - val_loss: 1.1074 - learning_rate: 6.2978e-04
# Epoch 112/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7264 - loss: 0.7137 - val_accuracy: 0.6400 - val_loss: 1.0608 - learning_rate: 6.2345e-04
# Epoch 113/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7650 - loss: 0.7025 - val_accuracy: 0.5750 - val_loss: 1.1424 - learning_rate: 6.1711e-04
# Epoch 114/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7385 - loss: 0.7215 - val_accuracy: 0.4600 - val_loss: 1.9436 - learning_rate: 6.1074e-04
# Epoch 115/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6990 - loss: 0.7730 - val_accuracy: 0.5200 - val_loss: 1.4495 - learning_rate: 6.0435e-04
# Epoch 116/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7097 - loss: 0.7703 - val_accuracy: 0.5600 - val_loss: 1.3588 - learning_rate: 5.9795e-04
# Epoch 117/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7315 - loss: 0.7685 - val_accuracy: 0.5800 - val_loss: 1.3103 - learning_rate: 5.9153e-04
# Epoch 118/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7453 - loss: 0.7083 - val_accuracy: 0.6000 - val_loss: 1.2904 - learning_rate: 5.8509e-04
# Epoch 119/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7719 - loss: 0.6717 - val_accuracy: 0.6000 - val_loss: 1.1924 - learning_rate: 5.7864e-04
# Epoch 120/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7255 - loss: 0.7589 - val_accuracy: 0.6200 - val_loss: 1.2122 - learning_rate: 5.7217e-04
# Epoch 121/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7392 - loss: 0.7352 - val_accuracy: 0.6000 - val_loss: 1.2981 - learning_rate: 5.6570e-04
# Epoch 122/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7338 - loss: 0.7303 - val_accuracy: 0.6450 - val_loss: 1.0783 - learning_rate: 5.5921e-04
# Epoch 123/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7396 - loss: 0.7299 - val_accuracy: 0.5350 - val_loss: 1.3448 - learning_rate: 5.5271e-04
# Epoch 124/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7426 - loss: 0.6940 - val_accuracy: 0.5900 - val_loss: 1.2151 - learning_rate: 5.4621e-04
# Epoch 125/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7378 - loss: 0.7133 - val_accuracy: 0.6650 - val_loss: 1.0030 - learning_rate: 5.3969e-04
# Epoch 126/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7490 - loss: 0.6864 - val_accuracy: 0.6600 - val_loss: 0.9793 - learning_rate: 5.3317e-04
# Epoch 127/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7632 - loss: 0.6935 - val_accuracy: 0.5950 - val_loss: 1.1824 - learning_rate: 5.2664e-04
# Epoch 128/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7606 - loss: 0.6865 - val_accuracy: 0.7000 - val_loss: 0.8544 - learning_rate: 5.2011e-04
# Epoch 129/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7652 - loss: 0.6865 - val_accuracy: 0.6450 - val_loss: 1.0578 - learning_rate: 5.1358e-04
# Epoch 130/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7772 - loss: 0.7066 - val_accuracy: 0.6650 - val_loss: 1.0187 - learning_rate: 5.0704e-04
# Epoch 131/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7622 - loss: 0.6805 - val_accuracy: 0.7000 - val_loss: 0.8583 - learning_rate: 5.0050e-04
# Epoch 132/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7998 - loss: 0.6220 - val_accuracy: 0.7150 - val_loss: 0.8462 - learning_rate: 4.9396e-04
# Epoch 133/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7497 - loss: 0.7029 - val_accuracy: 0.6700 - val_loss: 0.9149 - learning_rate: 4.8742e-04
# Epoch 134/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7828 - loss: 0.6722 - val_accuracy: 0.6900 - val_loss: 0.8931 - learning_rate: 4.8089e-04
# Epoch 135/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7806 - loss: 0.6444 - val_accuracy: 0.6550 - val_loss: 1.0390 - learning_rate: 4.7436e-04
# Epoch 136/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7624 - loss: 0.6770 - val_accuracy: 0.7000 - val_loss: 0.8800 - learning_rate: 4.6783e-04
# Epoch 137/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7558 - loss: 0.6613 - val_accuracy: 0.6850 - val_loss: 0.8945 - learning_rate: 4.6131e-04
# Epoch 138/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7980 - loss: 0.6210 - val_accuracy: 0.6350 - val_loss: 1.0095 - learning_rate: 4.5479e-04
# Epoch 139/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7388 - loss: 0.6914 - val_accuracy: 0.5000 - val_loss: 1.6252 - learning_rate: 4.4829e-04
# Epoch 140/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7801 - loss: 0.6357 - val_accuracy: 0.6050 - val_loss: 1.1137 - learning_rate: 4.4179e-04
# Epoch 141/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7752 - loss: 0.6509 - val_accuracy: 0.6400 - val_loss: 1.0887 - learning_rate: 4.3530e-04
# Epoch 142/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7459 - loss: 0.7003 - val_accuracy: 0.6800 - val_loss: 0.8789 - learning_rate: 4.2883e-04
# Epoch 143/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7681 - loss: 0.6109 - val_accuracy: 0.6950 - val_loss: 0.8973 - learning_rate: 4.2236e-04
# Epoch 144/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7639 - loss: 0.6333 - val_accuracy: 0.6450 - val_loss: 1.0663 - learning_rate: 4.1591e-04
# Epoch 145/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7502 - loss: 0.6528 - val_accuracy: 0.6800 - val_loss: 0.8903 - learning_rate: 4.0947e-04
# Epoch 146/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7999 - loss: 0.6160 - val_accuracy: 0.6200 - val_loss: 1.1135 - learning_rate: 4.0305e-04
# Epoch 147/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7676 - loss: 0.6803 - val_accuracy: 0.6500 - val_loss: 0.9934 - learning_rate: 3.9665e-04
# Epoch 148/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7718 - loss: 0.6344 - val_accuracy: 0.6600 - val_loss: 0.9665 - learning_rate: 3.9026e-04
# Epoch 149/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7777 - loss: 0.6226 - val_accuracy: 0.6800 - val_loss: 0.9533 - learning_rate: 3.8389e-04
# Epoch 150/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7752 - loss: 0.6229 - val_accuracy: 0.6400 - val_loss: 0.9789 - learning_rate: 3.7755e-04
# Epoch 151/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7724 - loss: 0.6446 - val_accuracy: 0.6550 - val_loss: 0.9495 - learning_rate: 3.7122e-04
# Epoch 152/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8044 - loss: 0.6105 - val_accuracy: 0.6850 - val_loss: 0.8680 - learning_rate: 3.6492e-04
# Epoch 153/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7857 - loss: 0.6105 - val_accuracy: 0.7150 - val_loss: 0.8428 - learning_rate: 3.5863e-04
# Epoch 154/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7863 - loss: 0.6024 - val_accuracy: 0.6800 - val_loss: 0.9991 - learning_rate: 3.5238e-04
# Epoch 155/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8007 - loss: 0.6103 - val_accuracy: 0.6800 - val_loss: 0.9544 - learning_rate: 3.4615e-04
# Epoch 156/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7869 - loss: 0.6355 - val_accuracy: 0.7000 - val_loss: 0.8576 - learning_rate: 3.3994e-04
# Epoch 157/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7772 - loss: 0.6362 - val_accuracy: 0.7300 - val_loss: 0.8154 - learning_rate: 3.3376e-04
# Epoch 158/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7742 - loss: 0.6424 - val_accuracy: 0.7050 - val_loss: 0.8733 - learning_rate: 3.2761e-04
# Epoch 159/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7757 - loss: 0.6141 - val_accuracy: 0.7250 - val_loss: 0.8325 - learning_rate: 3.2150e-04
# Epoch 160/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7859 - loss: 0.6420 - val_accuracy: 0.7300 - val_loss: 0.8086 - learning_rate: 3.1541e-04
# Epoch 161/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7976 - loss: 0.6073 - val_accuracy: 0.7450 - val_loss: 0.7952 - learning_rate: 3.0935e-04
# Epoch 162/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7926 - loss: 0.5937 - val_accuracy: 0.6850 - val_loss: 0.9105 - learning_rate: 3.0333e-04
# Epoch 163/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7726 - loss: 0.6139 - val_accuracy: 0.6950 - val_loss: 0.8701 - learning_rate: 2.9734e-04
# Epoch 164/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7687 - loss: 0.6382 - val_accuracy: 0.7150 - val_loss: 0.8094 - learning_rate: 2.9138e-04
# Epoch 165/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7767 - loss: 0.6147 - val_accuracy: 0.7200 - val_loss: 0.8671 - learning_rate: 2.8546e-04
# Epoch 166/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7990 - loss: 0.5708 - val_accuracy: 0.7000 - val_loss: 0.8141 - learning_rate: 2.7958e-04
# Epoch 167/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8253 - loss: 0.5545 - val_accuracy: 0.7250 - val_loss: 0.7666 - learning_rate: 2.7373e-04
# Epoch 168/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7801 - loss: 0.6035 - val_accuracy: 0.7250 - val_loss: 0.7538 - learning_rate: 2.6793e-04
# Epoch 169/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7913 - loss: 0.5962 - val_accuracy: 0.7400 - val_loss: 0.7754 - learning_rate: 2.6216e-04
# Epoch 170/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7676 - loss: 0.6070 - val_accuracy: 0.7400 - val_loss: 0.7655 - learning_rate: 2.5643e-04
# Epoch 171/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8004 - loss: 0.5796 - val_accuracy: 0.7450 - val_loss: 0.7852 - learning_rate: 2.5075e-04
# Epoch 172/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8138 - loss: 0.5907 - val_accuracy: 0.7300 - val_loss: 0.7685 - learning_rate: 2.4511e-04
# Epoch 173/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8226 - loss: 0.5408 - val_accuracy: 0.7250 - val_loss: 0.7794 - learning_rate: 2.3951e-04
# Epoch 174/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7994 - loss: 0.5749 - val_accuracy: 0.7050 - val_loss: 0.8223 - learning_rate: 2.3396e-04
# Epoch 175/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8006 - loss: 0.5483 - val_accuracy: 0.7100 - val_loss: 0.8202 - learning_rate: 2.2845e-04
# Epoch 176/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7812 - loss: 0.5969 - val_accuracy: 0.7150 - val_loss: 0.7912 - learning_rate: 2.2299e-04
# Epoch 177/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7962 - loss: 0.5638 - val_accuracy: 0.7100 - val_loss: 0.7709 - learning_rate: 2.1758e-04
# Epoch 178/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7977 - loss: 0.6004 - val_accuracy: 0.7250 - val_loss: 0.7591 - learning_rate: 2.1222e-04
# Epoch 179/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8174 - loss: 0.5681 - val_accuracy: 0.7100 - val_loss: 0.7896 - learning_rate: 2.0690e-04
# Epoch 180/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8181 - loss: 0.5256 - val_accuracy: 0.7250 - val_loss: 0.8068 - learning_rate: 2.0164e-04
# Epoch 181/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8204 - loss: 0.5560 - val_accuracy: 0.7150 - val_loss: 0.8714 - learning_rate: 1.9642e-04
# Epoch 182/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8192 - loss: 0.5415 - val_accuracy: 0.7150 - val_loss: 0.8377 - learning_rate: 1.9126e-04
# Epoch 183/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7997 - loss: 0.5778 - val_accuracy: 0.7250 - val_loss: 0.8559 - learning_rate: 1.8615e-04
# Epoch 184/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7770 - loss: 0.6094 - val_accuracy: 0.7250 - val_loss: 0.8334 - learning_rate: 1.8110e-04
# Epoch 185/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7979 - loss: 0.5756 - val_accuracy: 0.7250 - val_loss: 0.8485 - learning_rate: 1.7610e-04
# Epoch 186/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7983 - loss: 0.5589 - val_accuracy: 0.7250 - val_loss: 0.9021 - learning_rate: 1.7116e-04
# Epoch 187/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8123 - loss: 0.5365 - val_accuracy: 0.7250 - val_loss: 0.8403 - learning_rate: 1.6627e-04
# Epoch 188/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8227 - loss: 0.5333 - val_accuracy: 0.7450 - val_loss: 0.8002 - learning_rate: 1.6144e-04
# Epoch 189/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8366 - loss: 0.5295 - val_accuracy: 0.7100 - val_loss: 0.7997 - learning_rate: 1.5667e-04
# Epoch 190/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8196 - loss: 0.5364 - val_accuracy: 0.7150 - val_loss: 0.8008 - learning_rate: 1.5195e-04
# Epoch 191/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7694 - loss: 0.6104 - val_accuracy: 0.7100 - val_loss: 0.8326 - learning_rate: 1.4730e-04
# Epoch 192/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8009 - loss: 0.5787 - val_accuracy: 0.7250 - val_loss: 0.8090 - learning_rate: 1.4271e-04
# Epoch 193/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8142 - loss: 0.5523 - val_accuracy: 0.7050 - val_loss: 0.8448 - learning_rate: 1.3818e-04
# Epoch 194/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7945 - loss: 0.5808 - val_accuracy: 0.7300 - val_loss: 0.8066 - learning_rate: 1.3371e-04
# Epoch 195/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8179 - loss: 0.5518 - val_accuracy: 0.7500 - val_loss: 0.7942 - learning_rate: 1.2930e-04
# Epoch 196/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8223 - loss: 0.5297 - val_accuracy: 0.7500 - val_loss: 0.7993 - learning_rate: 1.2496e-04
# Epoch 197/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7935 - loss: 0.5933 - val_accuracy: 0.7350 - val_loss: 0.7989 - learning_rate: 1.2068e-04
# Epoch 198/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8008 - loss: 0.5412 - val_accuracy: 0.7100 - val_loss: 0.7973 - learning_rate: 1.1646e-04
# Epoch 199/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7918 - loss: 0.5638 - val_accuracy: 0.7150 - val_loss: 0.8134 - learning_rate: 1.1232e-04
# Epoch 200/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8102 - loss: 0.5436 - val_accuracy: 0.7250 - val_loss: 0.8039 - learning_rate: 1.0823e-04
# Epoch 201/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8062 - loss: 0.5703 - val_accuracy: 0.7050 - val_loss: 0.7796 - learning_rate: 1.0422e-04
# Epoch 202/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8211 - loss: 0.5396 - val_accuracy: 0.7000 - val_loss: 0.7816 - learning_rate: 1.0027e-04
# Epoch 203/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8229 - loss: 0.5233 - val_accuracy: 0.7150 - val_loss: 0.7885 - learning_rate: 9.6396e-05
# Epoch 204/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8243 - loss: 0.5520 - val_accuracy: 0.6950 - val_loss: 0.8163 - learning_rate: 9.2588e-05
# Epoch 205/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8182 - loss: 0.5501 - val_accuracy: 0.7000 - val_loss: 0.7880 - learning_rate: 8.8849e-05
# Epoch 206/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7997 - loss: 0.5798 - val_accuracy: 0.7300 - val_loss: 0.7777 - learning_rate: 8.5181e-05
# Epoch 207/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8396 - loss: 0.5214 - val_accuracy: 0.7300 - val_loss: 0.7638 - learning_rate: 8.1584e-05
# Epoch 208/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8053 - loss: 0.5541 - val_accuracy: 0.7350 - val_loss: 0.7593 - learning_rate: 7.8059e-05
# Epoch 209/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8086 - loss: 0.5468 - val_accuracy: 0.7400 - val_loss: 0.7522 - learning_rate: 7.4606e-05
# Epoch 210/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7853 - loss: 0.5959 - val_accuracy: 0.7300 - val_loss: 0.7656 - learning_rate: 7.1226e-05
# Epoch 211/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8114 - loss: 0.5213 - val_accuracy: 0.7300 - val_loss: 0.7753 - learning_rate: 6.7920e-05
# Epoch 212/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7932 - loss: 0.5620 - val_accuracy: 0.7450 - val_loss: 0.7671 - learning_rate: 6.4688e-05
# Epoch 213/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8324 - loss: 0.5555 - val_accuracy: 0.7450 - val_loss: 0.7751 - learning_rate: 6.1531e-05
# Epoch 214/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8127 - loss: 0.5353 - val_accuracy: 0.7350 - val_loss: 0.7674 - learning_rate: 5.8449e-05
# Epoch 215/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8194 - loss: 0.5202 - val_accuracy: 0.7300 - val_loss: 0.7640 - learning_rate: 5.5442e-05
# Epoch 216/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8098 - loss: 0.5737 - val_accuracy: 0.7400 - val_loss: 0.7589 - learning_rate: 5.2512e-05
# Epoch 217/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8262 - loss: 0.5243 - val_accuracy: 0.7450 - val_loss: 0.7563 - learning_rate: 4.9659e-05
# Epoch 218/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7982 - loss: 0.5631 - val_accuracy: 0.7400 - val_loss: 0.7689 - learning_rate: 4.6882e-05
# Epoch 219/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8383 - loss: 0.5400 - val_accuracy: 0.7450 - val_loss: 0.7697 - learning_rate: 4.4184e-05
# Epoch 220/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8094 - loss: 0.5745 - val_accuracy: 0.7400 - val_loss: 0.7671 - learning_rate: 4.1564e-05
# Epoch 221/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8223 - loss: 0.5371 - val_accuracy: 0.7250 - val_loss: 0.7759 - learning_rate: 3.9022e-05
# Epoch 222/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8342 - loss: 0.4902 - val_accuracy: 0.7300 - val_loss: 0.7772 - learning_rate: 3.6560e-05
# Epoch 223/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8006 - loss: 0.5542 - val_accuracy: 0.7400 - val_loss: 0.7699 - learning_rate: 3.4177e-05
# Epoch 224/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8324 - loss: 0.5277 - val_accuracy: 0.7450 - val_loss: 0.7707 - learning_rate: 3.1873e-05
# Epoch 225/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8209 - loss: 0.5435 - val_accuracy: 0.7450 - val_loss: 0.7538 - learning_rate: 2.9651e-05
# Epoch 226/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8253 - loss: 0.5337 - val_accuracy: 0.7350 - val_loss: 0.7551 - learning_rate: 2.7508e-05
# Epoch 227/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8090 - loss: 0.5412 - val_accuracy: 0.7300 - val_loss: 0.7567 - learning_rate: 2.5447e-05
# Epoch 228/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8403 - loss: 0.4974 - val_accuracy: 0.7350 - val_loss: 0.7574 - learning_rate: 2.3468e-05
# Epoch 229/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8007 - loss: 0.5638 - val_accuracy: 0.7300 - val_loss: 0.7575 - learning_rate: 2.1570e-05
# Epoch 230/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8068 - loss: 0.5567 - val_accuracy: 0.7350 - val_loss: 0.7535 - learning_rate: 1.9754e-05
# Epoch 231/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7915 - loss: 0.5370 - val_accuracy: 0.7350 - val_loss: 0.7524 - learning_rate: 1.8020e-05
# Epoch 232/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8260 - loss: 0.5367 - val_accuracy: 0.7400 - val_loss: 0.7509 - learning_rate: 1.6369e-05
# Epoch 233/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8102 - loss: 0.5313 - val_accuracy: 0.7350 - val_loss: 0.7510 - learning_rate: 1.4801e-05
# Epoch 234/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7854 - loss: 0.5595 - val_accuracy: 0.7450 - val_loss: 0.7495 - learning_rate: 1.3317e-05
# Epoch 235/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7840 - loss: 0.5624 - val_accuracy: 0.7450 - val_loss: 0.7467 - learning_rate: 1.1915e-05
# Epoch 236/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8011 - loss: 0.5291 - val_accuracy: 0.7450 - val_loss: 0.7487 - learning_rate: 1.0598e-05
# Epoch 237/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8281 - loss: 0.5087 - val_accuracy: 0.7450 - val_loss: 0.7475 - learning_rate: 9.3642e-06
# Epoch 238/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8419 - loss: 0.4902 - val_accuracy: 0.7450 - val_loss: 0.7476 - learning_rate: 8.2147e-06
# Epoch 239/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8007 - loss: 0.5804 - val_accuracy: 0.7550 - val_loss: 0.7474 - learning_rate: 7.1497e-06
# Epoch 240/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7918 - loss: 0.5681 - val_accuracy: 0.7550 - val_loss: 0.7461 - learning_rate: 6.1691e-06
# Epoch 241/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8211 - loss: 0.5543 - val_accuracy: 0.7550 - val_loss: 0.7455 - learning_rate: 5.2733e-06
# Epoch 242/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8286 - loss: 0.5631 - val_accuracy: 0.7550 - val_loss: 0.7451 - learning_rate: 4.4623e-06
# Epoch 243/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8268 - loss: 0.5381 - val_accuracy: 0.7550 - val_loss: 0.7450 - learning_rate: 3.7363e-06
# Epoch 244/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8343 - loss: 0.5203 - val_accuracy: 0.7500 - val_loss: 0.7455 - learning_rate: 3.0954e-06
# Epoch 245/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8094 - loss: 0.5627 - val_accuracy: 0.7500 - val_loss: 0.7462 - learning_rate: 2.5398e-06
# Epoch 246/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8222 - loss: 0.5414 - val_accuracy: 0.7500 - val_loss: 0.7463 - learning_rate: 2.0695e-06
# Epoch 247/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7853 - loss: 0.5831 - val_accuracy: 0.7500 - val_loss: 0.7468 - learning_rate: 1.6845e-06
# Epoch 248/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8443 - loss: 0.5231 - val_accuracy: 0.7500 - val_loss: 0.7473 - learning_rate: 1.3851e-06
# Epoch 249/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7993 - loss: 0.5507 - val_accuracy: 0.7500 - val_loss: 0.7464 - learning_rate: 1.1712e-06
# Epoch 250/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7977 - loss: 0.5627 - val_accuracy: 0.7500 - val_loss: 0.7462 - learning_rate: 1.0428e-06
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 669ms/step - accuracy: 0.7417 - loss: 1.0387
# Test Loss: 0.9629576802253723
# Test Accuracy: 0.7450000047683716
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 773ms/step
# Predicted Labels: [1 2 6 5 9 9 9 2 4 5 0 0 8 0 9 4 8 5 2 1 2 6 0 2 9 1 8 4 5 5 6 2 5 4 1 6 9
#  4 0 3 8 5 7 2 5 5 6 1 4 9 0 9 4 5 8 3 4 1 1 9 6 8 8 9 3 9 2 1 9 2 6 8 1 7
#  8 4 3 7 7 7 9 8 8 4 5 2 4 4 2 5 6 8 6 3 3 5 5 2 2 8 6 0 8 7 6 2 3 3 6 3 2
#  2 1 2 9 2 1 9 8 7 1 0 5 9 5 1 6 4 6 3 6 3 7 5 7 2 3 9 8 8 5 3 3 9 2 4 4 5
#  1 4 7 1 1 0 9 2 6 5 1 0 4 9 4 5 8 9 8 2 7 3 6 5 0 2 7 1 7 8 2 3 9 4 2 4 1
#  7 6 2 2 2 0 1 4 7 4 2 2 1 2 2]
# True Labels: [1 0 6 5 0 2 9 2 4 5 0 0 8 0 9 3 8 5 3 9 2 6 0 2 0 1 7 8 5 5 6 2 5 4 1 6 9
#  4 2 3 8 9 7 0 5 5 6 1 4 7 4 6 4 5 8 3 3 1 1 8 6 8 8 9 3 9 9 1 9 7 6 8 1 7
#  8 4 3 7 7 7 3 7 8 4 5 9 8 4 9 5 6 8 6 3 2 5 5 2 8 8 6 0 8 7 6 9 3 3 6 3 0
#  0 1 2 1 2 1 9 8 7 3 0 5 9 8 1 6 4 6 3 6 4 7 5 7 2 3 2 3 8 5 0 3 0 2 4 4 0
#  1 4 7 1 1 0 9 0 6 5 1 0 3 3 4 5 8 9 9 2 7 0 6 5 0 9 7 1 7 4 2 3 6 4 9 4 1
#  7 6 2 5 2 4 1 7 7 4 2 2 1 9 2]

# %%
plot_model_training(music_genre_hybrid_model.history)
plot_prediction_heatmap(music_genre_hybrid_model, padded_test_features, test_labels, label_encoder)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 710ms/step

# %% [markdown]
# # Set up for Baseline Models

# %%
# Set random seeds for reproducibility
SEED = 42
np.random.seed(SEED)

# Function to extract and flatten padded features for Logistic Regression model
def extract_baseline_features(features_dict):
    combined_features = []

    for feature in features_dict:
        if 'vggish_input' in feature:
            # Skip vggish features
            continue
        feature_data = features_dict[feature]
        # Flatten 3D shape (num_samples, sequence_length, 1) to 2D shape (num_samples, sequence_length)
        feature_data_flattened = feature_data.reshape(feature_data.shape[0], -1)
        combined_features.append(feature_data_flattened)

    # Check if there are any features to concatenate
    if len(combined_features) == 0:
        return np.array([])

    # Horizontally stack the selected features
    combined_features = np.hstack(combined_features)

    return combined_features

# Extract and pad features for training, validation, and testing
train_baseline = extract_baseline_features(padded_train_features)
val_baseline= extract_baseline_features(padded_val_features)
test_baseline = extract_baseline_features(padded_test_features)

# Convert labels back to original names
target_names = label_encoder.inverse_transform(range(len(label_encoder.classes_)))

# %% [markdown]
# # Baseline for CNNs: Logistic

# %%
# Create Logistic regression model
logistic = LogisticRegression(
    C=5,
    class_weight='balanced',
    max_iter=1000,
    n_jobs=-1,
    random_state=SEED)

logistic.fit(train_baseline, train_labels)

# Predict on validation and test sets
val_predictions_logistic = logistic.predict(val_baseline)
val_accuracy_logistic = accuracy_score(val_labels, val_predictions_logistic)

test_predictions_logistic = logistic.predict(test_baseline)
test_accuracy_logistic = accuracy_score(test_labels, test_predictions_logistic)

print(f"Validation Accuracy for Logistic: {val_accuracy_logistic :.4f}")
print(f"Test Accuracy for Logistic: {test_accuracy_logistic:.4f}")
print("Classification Report for Logistic:\n", classification_report(test_labels, test_predictions_logistic, target_names=target_names))
# Out:
# Validation Accuracy for Logistic: 0.4300
# Test Accuracy for Logistic: 0.4500
# Classification Report for Logistic:
#                precision    recall  f1-score   support
#
#        blues       0.17      0.30      0.21        20
#    classical       0.68      0.85      0.76        20
#      country       0.38      0.45      0.41        20
#        disco       0.43      0.15      0.22        20
#       hiphop       0.50      0.25      0.33        20
#         jazz       0.36      0.70      0.47        20
#        metal       0.75      0.60      0.67        20
#          pop       0.60      0.75      0.67        20
#       reggae       0.75      0.30      0.43        20
#         rock       0.30      0.15      0.20        20
#
#     accuracy                           0.45       200
#    macro avg       0.49      0.45      0.44       200
# weighted avg       0.49      0.45      0.44       200

# %% [markdown]
# # Baseline for RNNs: SGD

# %%
# Create SGD Classifier model
sgd = SGDClassifier(loss='hinge',
                          alpha=1e-4,
                          max_iter=1000,
                          class_weight='balanced',
                          random_state=SEED)

# Train SGD Classifier
sgd.fit(train_baseline, train_labels)

# Predict on validation and test sets
val_predictions_sgd = sgd.predict(val_baseline)
val_accuracy_sgd = accuracy_score(val_labels, val_predictions_sgd)

test_predictions_sgd = sgd.predict(test_baseline)
test_accuracy_sgd = accuracy_score(test_labels, test_predictions_sgd)

print(f"Validation Accuracy for SGD Classifier: {val_accuracy_sgd:.4f}")
print(f"Test Accuracy for SGD Classifier: {test_accuracy_sgd:.4f}")
print("Test Classification Report for SGD Classifier:\n", classification_report(test_labels, test_predictions_sgd, target_names=target_names))
# Out:
# Validation Accuracy for SGD Classifier: 0.3800
# Test Accuracy for SGD Classifier: 0.3800
# Test Classification Report for SGD Classifier:
#                precision    recall  f1-score   support
#
#        blues       0.00      0.00      0.00        20
#    classical       0.54      0.75      0.62        20
#      country       0.25      0.70      0.37        20
#        disco       0.33      0.10      0.15        20
#       hiphop       0.19      0.25      0.21        20
#         jazz       0.36      0.20      0.26        20
#        metal       0.53      0.95      0.68        20
#          pop       0.61      0.55      0.58        20
#       reggae       0.31      0.20      0.24        20
#         rock       0.40      0.10      0.16        20
#
#     accuracy                           0.38       200
#    macro avg       0.35      0.38      0.33       200
# weighted avg       0.35      0.38      0.33       200
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# # Baseline for Hybrid: Random Forest

# %%
# Create Random Forest model
rf = RandomForestClassifier(n_estimators=300,
                            class_weight='balanced',
                            min_samples_leaf=3,
                            max_depth=10,
                            n_jobs=-1,
                            random_state=SEED)

rf.fit(train_baseline, train_labels)

val_predictions_rf = rf.predict(val_baseline)
val_accuracy_rf = accuracy_score(val_labels, val_predictions_rf)

test_predictions_rf = rf.predict(test_baseline)
test_accuracy_rf = accuracy_score(test_labels, test_predictions_rf)

print(f"Validation Accuracy for Random Forest: {val_accuracy_rf:.4f}")
print(f"Test Accuracy for Random Forest: {test_accuracy_rf:.4f}")
print("Test Classification Report for Random Forest:\n", classification_report(test_labels, test_predictions_rf, target_names=target_names))
# Out:
# Validation Accuracy for Random Forest: 0.5450
# Test Accuracy for Random Forest: 0.5500
# Test Classification Report for Random Forest:
#                precision    recall  f1-score   support
#
#        blues       0.38      0.15      0.21        20
#    classical       0.70      0.80      0.74        20
#      country       0.31      0.25      0.28        20
#        disco       0.45      0.25      0.32        20
#       hiphop       0.62      0.50      0.56        20
#         jazz       0.42      0.75      0.54        20
#        metal       0.82      0.90      0.86        20
#          pop       0.60      0.90      0.72        20
#       reggae       0.75      0.60      0.67        20
#         rock       0.36      0.40      0.38        20
#
#     accuracy                           0.55       200
#    macro avg       0.54      0.55      0.53       200
# weighted avg       0.54      0.55      0.53       200
